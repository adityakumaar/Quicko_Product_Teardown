# %%
# importing the library
from google_play_scraper import Sort, reviews_all

# %%
# fetching all user reviews
result = reviews_all(
    'com.quicko.glyde',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='in', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
)

# %%
# displaying all user reviews
import pprint
pprint.pprint(result)
# Out:
# [{'at': datetime.datetime(2023, 7, 12, 22, 43, 40),
#   'content': 'This is genuine review. I wanted to say thank you glyde. It was '
#              'really awesome. Only drawback is your app is little confusing. '
#              'There should be a confirmation button, I was getting confused '
#              'because I was unware that it automatically saves information. By '
#              'the way many many thanks to you',
#   'repliedAt': datetime.datetime(2023, 7, 12, 23, 3, 34),
#   'replyContent': "Hey there! Nachiketa here, I'm the developer of the app. "
#                   "We're over the moon that you had a good experience "
#                   'glyding!\n'
#                   '\n'
#                   "We hear you and we'll do our best to make the app even "
#                   'simpler to use.',
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': '2d1aa50c-5922-4055-93d0-4604ea3a99b2',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcrUb9kpFutmWxYAKoQVOl9_kyx6woYEK10SoW_Gx2Mig=mo',
#   'userName': 'Himadri Debnath'},
#  {'at': datetime.datetime(2023, 7, 11, 18, 53, 54),
#   'content': 'This is the best tax filing application. Best interface in '
#              'quicko website.Its is so easy to understand the terminology of '
#              'income tax here and filing tax return is so quick .It is highly '
#              'recommend to use this especially for salaried person.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': '20d2b63c-a26a-4ffe-a847-3e545c19bf95',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdySO1Nr6RGie_fIa4Xcz6XTP2VONIzpBGE4jeqrZhTzA=mo',
#   'userName': 'RAKESH KUMAR'},
#  {'at': datetime.datetime(2023, 7, 16, 17, 1, 9),
#   'content': 'Very user friendly app. It retrieves most of the data, you need '
#              'not to key in it again and again.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': '60ecaae0-42df-4a74-bb94-1b27448f23c7',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteno6gkbYONZ0P5o44-zkdgnNUEoiiS7qXf4qzizPkg=mo',
#   'userName': 'Jain Shikhar'},
#  {'at': datetime.datetime(2023, 7, 3, 9, 28, 36),
#   'content': 'Application is not working properly while filling the itr and '
#              'also not able to everify. As you are charging very high as '
#              'compared to clear tax,so your system should be stable',
#   'repliedAt': datetime.datetime(2023, 7, 3, 9, 51, 3),
#   'replyContent': "Hey there, Nachiketa here. I'm the developer on glyde. If "
#                   "you're facing any issues while e-filing, our team would be "
#                   'more than happy to help you out if you could reach out to '
#                   'us by raising a ticket from the app!',
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': 'c92b1418-bb81-43ef-bb76-997ffcd96179',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtczko7txspGH8bHIBLiSB3eCSv52s28Z6w7pb1RdVaJog=mo',
#   'userName': 'susanta roy'},
#  {'at': datetime.datetime(2023, 7, 20, 3, 38, 39),
#   'content': 'Third class app as well as support people with full of attitude, '
#              'I got wrost experience, once you pay money they will forget '
#              'you... Wrost experience',
#   'repliedAt': datetime.datetime(2023, 7, 20, 5, 21, 40),
#   'replyContent': "Hey Pradip, Nachiketa here. I'm the developer of the app. \n"
#                   '\n'
#                   "I can see that you're already in conversation with our team "
#                   "about your situation and rest assured they'll help you "
#                   'succeed on the app like all our other users have. If you '
#                   "have any other questions, feel free to email us and I'll "
#                   'make sure that our team reaches out as soon as possible.',
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': '6938ede1-5a4f-4988-925f-d17db7f62d37',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteGBZgSfQ4nexemeGVO2ImNUy1VJyPtH7RZBexmWyNZ=mo',
#   'userName': 'pradip kshirsagar'},
#  {'at': datetime.datetime(2023, 7, 16, 10, 3, 52),
#   'content': 'I took an annual subscription but my broker ICICI securities is '
#              'not in the app. Moreover there is no arrangement for uploading '
#              'P/L statement.',
#   'repliedAt': datetime.datetime(2023, 7, 16, 11, 33, 11),
#   'replyContent': "Hey Vijay, Nachiketa here. I'm the developer on glyde. \n"
#                   '\n'
#                   'We are working with ICICI Securities to make the '
#                   'integration available as soon as possible and expect it to '
#                   'go live within a week.',
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': '05071da6-e667-4154-bc81-65fee9b86fe9',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRYy61PDeUrajtoDqz9phH3iPS6r3ua899VYNdXvsSAYVM',
#   'userName': 'Vijay Veer Singh'},
#  {'at': datetime.datetime(2023, 6, 20, 14, 55, 31),
#   'content': 'Awesome and wonderful app developed. I have never seen this type '
#              'of advanced app. I was facing acute stress in filing ITR and it '
#              'has been resolved by login to the GLYDE. Thanks for Glyde team '
#              'for developing such a wonderful app.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.5.2',
#   'reviewId': '4e2feed4-519a-4cec-8b46-e6054afe3d89',
#   'score': 5,
#   'thumbsUpCount': 9,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRHCjc-_90CYWWqOo-HE_KelGr5Fo65jgzfEK6FjT1V8Dg',
#   'userName': 'Valluri Subrahmanyam'},
#  {'at': datetime.datetime(2023, 5, 18, 11, 33, 42),
#   'content': 'Amazing app. I was able to prepare my income tax return in '
#              'minutes. Also, love the advance tax calculator feature.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.5.2',
#   'reviewId': '50f0416e-3b4d-461a-b158-2f236531cdad',
#   'score': 5,
#   'thumbsUpCount': 6,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtf6fQTfECg-_anZFUFdmRLV8aph-r06RSdJUOCktB7q=mo',
#   'userName': 'Kunal Parekh'},
#  {'at': datetime.datetime(2023, 7, 11, 8, 23, 12),
#   'content': 'Pathetic service. App is ok, but service from the vendor is '
#              "absolutely pathetic and you won't be able to file your taxes on "
#              'time as no one responds to your queries and you would be forced '
#              'to buy Pro Plan.',
#   'repliedAt': datetime.datetime(2023, 7, 11, 19, 7, 25),
#   'replyContent': "Hello Mr Ray, Nachiketa here. I'm the developer on glyde. \n"
#                   '\n'
#                   "Thanks for trying the app out. I'm sorry that you had an "
#                   'inconvenient experience. \n'
#                   '\n'
#                   'If you can send an email at glyde@quicko.com and refer to '
#                   "this conversation, I'd be happy to personally take a look "
#                   'at your situation and help you solve your queries.',
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': 'f1d78c38-2bb9-4b97-a822-522be20b869d',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteoAHL7Kip2c_1bFJdwFBn_zaMgi1ddJ6bme1XoCka2=mo',
#   'userName': 'Mr Ray'},
#  {'at': datetime.datetime(2023, 6, 10, 16, 20, 33),
#   'content': 'No proper guidance, what happens after we review? Waiting for '
#              'last 3 days...no option to efile visible yet as shown in the '
#              'video. Pathetic. Even the Json downloaded doesnt get uploaded on '
#              'IT dept portal for e-filing.',
#   'repliedAt': datetime.datetime(2023, 6, 10, 16, 6, 32),
#   'replyContent': 'Hey Abhijit, Nachiketa here, the developer on glyde. We are '
#                   'working with ITD to enable e-filing as soon as we can. '
#                   'Meanwhile, if you want to e-file, you can download the JSON '
#                   'file after review from the app and upload it to the ITD '
#                   'Portal. If you need more help, feel free to reach out by '
#                   'raising a ticket from the app!',
#   'reviewCreatedVersion': '2.5.2',
#   'reviewId': '85b382cb-1de8-4917-ac58-4997b428b488',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRUHps7BGhThgxtXRtj0a1WMf9jLxQVZiMzswZeHKNrPIEh',
#   'userName': 'Abhijit P'},
#  {'at': datetime.datetime(2023, 5, 18, 11, 36, 10),
#   'content': 'Amazing app. Never been too easy filing. Filed my entire '
#              "family's return using the app. Amazing experience!",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.4.4',
#   'reviewId': 'eb68cbd3-4a60-4cee-85fe-4c122b508348',
#   'score': 5,
#   'thumbsUpCount': 4,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSTqGsBSKoQSM8r6DxTgfeNdw56JKmw7clWZ6491Uk517Rd',
#   'userName': 'Sedimbi Satya Pramod'},
#  {'at': datetime.datetime(2023, 5, 18, 13, 7, 22),
#   'content': 'Extremely helpful app and one-stop solution for all the '
#              'tax-related issues. Good work!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.5.2',
#   'reviewId': 'c135389b-ad0a-4ffc-af0a-811a04a6bc8f',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSl1wF6QxXBwfD3Zq05lr8ZaaYd8awCguMmuaJftOuS3hc',
#   'userName': 'Amitabh Shukla'},
#  {'at': datetime.datetime(2023, 7, 4, 10, 11, 26),
#   'content': 'Since last 7 days error of outage is appearing while submitting '
#              'file with meagre amount of tax challan. Not able to find any '
#              'solution',
#   'repliedAt': datetime.datetime(2023, 7, 4, 10, 47, 6),
#   'replyContent': "Hey Ravi, Nachiketa here. I'm the developer of the app. Due "
#                   "to changes in rules for tax payment by ITD, we've had to "
#                   'pause the feature momentarily. \n'
#                   '\n'
#                   'You can still pay your taxes from the ITD Portal, report '
#                   'tax credits and e-file through the app. \n'
#                   '\n'
#                   'If you need any further help, you can raise a ticket from '
#                   'the app!',
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': '44d0a696-d3e6-45ec-87bc-c969b796a6ac',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQW6Kur0OGoxBOQ-H37t5LnHAPp1_KaQ6eyDezM4yP9zbY',
#   'userName': 'Ravi Paliwal'},
#  {'at': datetime.datetime(2023, 7, 17, 9, 22, 10),
#   'content': 'Wow..just Wow app..i was seaching on youtube about Itr3 and it '
#              'was so difficult..Zerodha recommend me this app n it was magic.. '
#              'So simple tax filling process..loved it .5 star.. Thanks Glyde '
#              'and team.. Kudos',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': '02244297-df83-48cb-857d-9dae57b6af22',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRnPY_f0LkLR_3O8BbJoC2Te1UwuxpQqShVyS1UkxdwTGs',
#   'userName': 'Prem Singh Bisht'},
#  {'at': datetime.datetime(2023, 7, 12, 16, 44, 51),
#   'content': 'Absolutely incredible . . Never thought filing would be so '
#              'easier . .',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': 'c045010d-3d69-4df5-8442-ef4bd3d9f4c9',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteUdoStUFJ7afiioKtkZgFRTfTU6253pcFKCBuC4e68=mo',
#   'userName': 'Ragunath Iyue'},
#  {'at': datetime.datetime(2023, 7, 17, 14, 35, 15),
#   'content': 'Best itr filing application, user friendly, super application.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': '8b2b7251-d50b-42f1-b58f-53865b2303dd',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSX7Ookr6qEhQIiFYXE6YleJ2D8wHr378IAoMkoFRS7Uss',
#   'userName': 'Mahesh Ojha'},
#  {'at': datetime.datetime(2023, 7, 22, 17, 15, 26),
#   'content': 'Amazingly simple and intuitive',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': 'c56963d2-5622-47cc-afa4-8e322d454e7e',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQvlCwwx8THK4kRclk5mstBiiD6kTtEp_7f0JfVLo3ec7U',
#   'userName': 'kaushik raman'},
#  {'at': datetime.datetime(2023, 6, 27, 20, 24, 54),
#   'content': "Wonderful, you don't need to worry about tax and e-filing if "
#              "you're using glyde it covers everything you need.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.5.4',
#   'reviewId': 'a4a07449-5347-4c62-9997-44dcc86ba13f',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRvzcuU5QHnOHesTKWzr6DEelUwGflS5bW77bvAK33PHIU',
#   'userName': 'Harsh Agrawal'},
#  {'at': datetime.datetime(2023, 7, 21, 17, 50, 25),
#   'content': 'Nice Application and helpful for file income tax return.....',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': 'c454cc3d-d85f-4c46-b31a-9b18c4bc014a',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRv4PUeY6JrwkSF_N0_6zH90T2LohWZKQT2GOA6dJWE4kbj',
#   'userName': 'Deepak Kumar'},
#  {'at': datetime.datetime(2023, 6, 21, 17, 48, 46),
#   'content': 'App is not opening,It is showing update but already updated and '
#              'not opening',
#   'repliedAt': datetime.datetime(2023, 6, 21, 18, 16, 27),
#   'replyContent': "Hey Swarup, Nachiketa here. I'm the developer of the app. "
#                   'Sorry for the inconvenience! Google Play Store was facing '
#                   'some issues with processing our update. Please try again '
#                   'now.',
#   'reviewCreatedVersion': '2.5.2',
#   'reviewId': 'e18346cd-df21-4437-9ca3-88579ff70acc',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQqRMaEErsdzhDVyPd90uiBA6tK8euzGAQ-sqQheaqLGw',
#   'userName': 'Swarup Das'},
#  {'at': datetime.datetime(2023, 6, 20, 21, 15, 44),
#   'content': 'Easy-to-use and hassle-free free experience',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.5.2',
#   'reviewId': 'ddd286e7-a3cb-437e-aa6d-8506ce0c5f20',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTuawicbCgpqV24m2E7rF9ibbWP6MAoNd8iGgll5kBj8RM',
#   'userName': 'Rajesh Meena'},
#  {'at': datetime.datetime(2023, 5, 18, 13, 31, 34),
#   'content': 'loved the experience! Made taxes so easy. Hopefully the pay part '
#              'starts working soon',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.5.2',
#   'reviewId': 'dea2d740-bee2-4fa1-9981-dfe358b19904',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtd07TBU9LHKfHkKlKO6F35mvc2b9zTlUYZ5P_qaIDsO=mo',
#   'userName': 'Henil Shah'},
#  {'at': datetime.datetime(2023, 7, 2, 0, 32, 45),
#   'content': 'Would be great if support for ITR 4 is also added',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': '203e63e4-ddc7-49e1-855a-850317a9fca2',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSBlA-XmkNUUHppdyAegrdR2pFSRBhMFsbi11FtZmbVheE',
#   'userName': 'Khavin Shankar'},
#  {'at': datetime.datetime(2023, 6, 23, 17, 45, 26),
#   'content': 'Great App. Super easy tax filing.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.5.4',
#   'reviewId': 'fdded5fc-6474-40ab-b77d-4283faaf7220',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRmr0C27AXB-8IXTTc0IUFqtlOQ1vOoEgN4MgW83-se_R4k',
#   'userName': 'Utkarsh Shahane'},
#  {'at': datetime.datetime(2023, 6, 24, 18, 19, 10),
#   'content': 'quite smooth except for payment part',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.5.4',
#   'reviewId': 'df140b82-737c-47ab-bba4-ae251e4feb92',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQYaPqushWHTdRah_YTclnIq4xVdoim-VRAyvJ2U9FB7Q',
#   'userName': 'Aseem Kashyap'},
#  {'at': datetime.datetime(2023, 7, 19, 6, 16, 30),
#   'content': 'Sir, While file f&o losses from zerodha , it show non '
#              'speculative loss. But correct one is speculative !',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': '3186d41c-1545-409d-90bf-e053db55facd',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSh8Uwuhl57wgMiAjhnA4_TkbFGFZzrMCUZIDldVRJBYe8',
#   'userName': 'Mahesh Kumar'},
#  {'at': datetime.datetime(2023, 7, 21, 21, 7, 6),
#   'content': 'it was really great experience..with in short span done..',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': '06e13d0c-4520-4cd9-92a0-8b23151a48c5',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSCNmed-U9UYjdJgKh3GV7CX-l0a93vLN_qqtrltaX3v-Y',
#   'userName': 'Kamal Kumar'},
#  {'at': datetime.datetime(2023, 7, 15, 18, 36, 40),
#   'content': 'Beautifully designed. Super swift',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': 'c3c6db5c-303c-4321-9640-2cf349771a5e',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRwylB54iQZxn2EhU9ZredHH-ckH1ZpoYPeMc3s4N23DRE',
#   'userName': 'Rishi Jani'},
#  {'at': datetime.datetime(2023, 7, 17, 13, 42, 38),
#   'content': 'extremely friendly and comprehensive',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': '639c1793-2265-4a33-b16b-e41473daeb70',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRI20F9n3Z5P-yyhHKXLM6Fah8kb7fOXmVZR51unUp1Noo',
#   'userName': 'girish babu gogineni'},
#  {'at': datetime.datetime(2023, 7, 5, 9, 44, 13),
#   'content': 'Awesome app Great app for all users including new user',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': '2d5d1c93-0e71-46c2-b921-c68884e1bb10',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfPnOnr39RoRV60NOXamy4fSGle0GZEU0jfcwqt7Ikx=mo',
#   'userName': 'Ravi Khupse'},
#  {'at': datetime.datetime(2023, 7, 14, 15, 26, 37),
#   'content': 'For Zerodha users traded volume is more than 100 ...app is '
#              'charging amount. It is not fair. Pl see',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.2',
#   'reviewId': '0c867869-6dcd-4fe4-9f9a-8677d36976c1',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT43OS-cf9w9_W46XzjeVCIBlE_-T5ujpaeu5XIA6vu8PQ',
#   'userName': 'Vivek Goyal'},
#  {'at': datetime.datetime(2022, 7, 25, 15, 30, 29),
#   'content': 'Glyde is such a wonderful app. I was struggling with filling my '
#              'taxes. Even on sites like cleartax, it is so difficult to figure '
#              'out the right places to enter details. Glyde just made it so '
#              'smooth. I could figure out the details easily and also prefill '
#              'the values from ITD. It is the only app who had an auto import '
#              'feature for Paytm money which made importing investment details '
#              'a breeze. Also the team has designed a smooth and wonderful UI. '
#              'Kudos to them! Love this app! ❤️',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.2.1',
#   'reviewId': 'a3f9195a-caa0-4856-b43b-92019366ca6a',
#   'score': 5,
#   'thumbsUpCount': 35,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTIgGe4wd0XO6CLfYDEogOL9khIs93BCXs1grunX74g6cPS',
#   'userName': 'Lezwon Castellino'},
#  {'at': datetime.datetime(2021, 11, 25, 22, 22, 34),
#   'content': 'Great to see the team is still so much committed after '
#              'delivering consistent excellence. This is the initial version '
#              'but stil it brings e-filing on your fingertips. I must admit '
#              'that Quicko is really good at smoke signals they understands the '
#              'need of an hour. Wishing them all the success for their upcoming '
#              'versions with much more intuitive UI and amazing user experience '
#              'with awesome features.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '0.1.0',
#   'reviewId': '4ef8932f-bde8-4ebe-921c-20e51880f258',
#   'score': 5,
#   'thumbsUpCount': 53,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRxlSPvQ3yvRNkA32QF22HYkFt355dktSbyMbcI1jz6El4',
#   'userName': 'sahaj pathak'},
#  {'at': datetime.datetime(2023, 6, 22, 20, 35, 42),
#   'content': 'Smooth. fast. beautiful. useful',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.5.4',
#   'reviewId': '2d443a6b-cd1b-45e6-b324-6396c939b005',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTOQUU5vUGId3LiIFUojNi9hDCjcnur3vl-Io93I6sJ4Bqh',
#   'userName': 'Chetpally Sai Sumith'},
#  {'at': datetime.datetime(2022, 7, 28, 20, 56, 9),
#   'content': "Great app, the best for tax filing. It's easy, smooth and very "
#              'quick. Any novice can easily file tax using it. One thing '
#              'though, the desktop version is not available.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.2.2',
#   'reviewId': '9bab147b-089f-4b31-9dd7-4d0c3083c713',
#   'score': 5,
#   'thumbsUpCount': 20,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcgOR7hcSlClCU3wa33l819ic-vbvJlNeJeY9jzcvI7=mo',
#   'userName': 'B K'},
#  {'at': datetime.datetime(2023, 7, 3, 21, 21, 29),
#   'content': 'It has never been so easy.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': 'a076b34c-9605-4a57-a6c3-f24207c9945b',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQawjTcRqM9QAP4cBx3jJWzRUtfKbVQlMW1ws3kRsf8P_s',
#   'userName': 'Sonam Murarka'},
#  {'at': datetime.datetime(2023, 6, 20, 16, 52, 5),
#   'content': 'great and very easy app for itr',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.5.2',
#   'reviewId': 'f81f66dd-9a74-46c2-b99a-b0e9a51a793e',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRc-k1A7I9Z7Y_OYhiwerKbP2lNKdtEnDvDN8bZDjCG7ew',
#   'userName': 'Harsh Dutt Sharma'},
#  {'at': datetime.datetime(2023, 7, 8, 20, 2, 9),
#   'content': 'I kid you not, I really did Glyde through the ITR process! It '
#              "was my first time... let's see how it goes.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': '06fb708a-3523-43e0-bea2-a79efbce1355',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQtHkQrlFd9gajCk_1SE2k919bzpFlUmsOKrl3N40irLg',
#   'userName': 'Sai Skanda'},
#  {'at': datetime.datetime(2021, 12, 24, 17, 48, 57),
#   'content': 'First attempt: Onboarding failed at Enter PAN. The team quickly '
#              'responded and informed about a surge in new users creating a '
#              'snag at their servers. Second try: Onboarding went smoothly. '
#              'Really like the interface and the available options on the app. '
#              'Some of the features from their Website are marked as coming '
#              "soon. Can't wait to use these for the next tax cycle.",
#   'repliedAt': datetime.datetime(2021, 12, 24, 17, 34, 16),
#   'replyContent': 'Hey Rohit! Our servers hit a bit of a snag with all the '
#                   'taxpayers like you onboarding onto the app. We have '
#                   "addressed the issue; we are hoping you'd give us another "
#                   'shot and tell us how we did!',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '1244bd80-f674-433a-9967-dc7b1bbcf1de',
#   'score': 4,
#   'thumbsUpCount': 13,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRNhHhz5_NycXl9UPo1-8_RmC3SuDfnFKFjjZoSAJluXFxp',
#   'userName': 'Rohit C Kumar'},
#  {'at': datetime.datetime(2022, 2, 28, 13, 10, 36),
#   'content': 'It shows its waiting for a renewal for sync service from the '
#              'ITD, so its not doing anything automatically it gives you an '
#              'option to do things manually.. which kills the purpose of glyde '
#              'I feel.. how long would this fix take ? Also once i click manual '
#              "by mistake now it doesn't revert to automatic sync to ITD...",
#   'repliedAt': datetime.datetime(2022, 7, 20, 20, 1, 8),
#   'replyContent': "Hey Steve. We've updated our integration. The Autofill "
#                   'feature is up and running. If you have any further '
#                   'questions, you can reach out to us via help@quicko.com',
#   'reviewCreatedVersion': '1.2.7',
#   'reviewId': '4ed20b17-5e33-4079-9803-de16fbe83d83',
#   'score': 1,
#   'thumbsUpCount': 15,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteupNobi71kp1uGRjZvrsQCoxmgHEgPx2FUVP65aeJQ=mo',
#   'userName': 'Steve Anderson'},
#  {'at': datetime.datetime(2022, 3, 3, 7, 16, 42),
#   'content': "Hi team, I've created an account and later I logged out. Now if "
#              'i try to login again, it says taxpayer exists and shows me a '
#              "bug. I've reported the same. Also when the app was accessible, I "
#              'didnt open the ITR filing part. Infinite loading. Please look '
#              'into them. Thanks.',
#   'repliedAt': datetime.datetime(2022, 7, 24, 18, 38, 54),
#   'replyContent': 'Hey Santosh! We have been working hard incorporating all '
#                   'the feedback from users like yourself. Would love for you '
#                   'to give us another shot!',
#   'reviewCreatedVersion': '1.2.7',
#   'reviewId': '1e417322-797f-4df5-b834-9e7cdd9fea23',
#   'score': 3,
#   'thumbsUpCount': 9,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMR9_ax7gxsu5JcIw77Wf3DMqACe8SdAO2GJRG-A8rkF0NCl',
#   'userName': 'Santosh Kulkarni'},
#  {'at': datetime.datetime(2023, 7, 4, 15, 9, 12),
#   'content': 'Very convenient to use',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': 'f155537b-03bc-44fb-ae6b-2efe790f64f6',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteGU9paBpvYgTX3MOe49tPbnMtKhCIqm4d79F9as2_h=mo',
#   'userName': 'Hariprasath Logadasan'},
#  {'at': datetime.datetime(2021, 12, 23, 13, 35, 13),
#   'content': 'The app is not downloading, after 41%, the downloading gets '
#              'stuck. I have restarted the phone, clear the cache memory and '
#              'even changed the google account. Please resolve the issue at the '
#              'earliest.',
#   'repliedAt': datetime.datetime(2021, 12, 24, 20, 32, 16),
#   'replyContent': "Hi Jatin, we are sorry, our first impression wasn't that "
#                   'great. Some of you faced issues while signing up & others '
#                   'while onboarding. We are back up now. Would love for you to '
#                   'try it again. If we are able to meet your expectations, do '
#                   'let us know how we did this time around :)',
#   'reviewCreatedVersion': None,
#   'reviewId': '09da7dbc-c6ac-4159-b6ed-1defc5918bde',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQzMcRjbdpbAxPO4w_RWtvYqW-Q9lranMVD-aNhTrPsVg',
#   'userName': 'Jatin kumar'},
#  {'at': datetime.datetime(2021, 12, 30, 13, 41, 22),
#   'content': "Problem automatically solved, don't know how. ---------+ After "
#              "filling all things, on clicking let's file. After filling "
#              'credentials of income tax account, it shows Account login '
#              'required error. And comes back 3-4 times. 5 times it solved.',
#   'repliedAt': datetime.datetime(2021, 12, 30, 13, 31, 1),
#   'replyContent': 'Hey Nitin! Nachiketa here, the developer on glyde. Are you '
#                   'facing this issue every time you try to e-file? For any '
#                   'further assistance, you can reach out to help@quicko.com '
#                   "and we'd be happy to help you glyde better.",
#   'reviewCreatedVersion': '1.2.3',
#   'reviewId': '9079f1b0-b22d-418a-8a87-fac875569f89',
#   'score': 3,
#   'thumbsUpCount': 5,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMR7-x4Hokim1SycavfFJkRhn4k1wtDWRrOT-4GnPqfyoY4',
#   'userName': 'Nitin Jadhav'},
#  {'at': datetime.datetime(2022, 1, 1, 13, 47, 55),
#   'content': 'Ok finally was able to file my returns. But it was constant '
#              'checking, updating app numerous times. Hope yhe fixes now will '
#              "help file taxes easily next year. I'll give a 5 star if the "
#              'experience next year is smooth. There were a lot of hiccups this '
#              'year.',
#   'repliedAt': datetime.datetime(2021, 12, 31, 15, 7, 52),
#   'replyContent': 'Hey Bujji, we have published a fix for the issue you were '
#                   'facing. Thank you for your patience!',
#   'reviewCreatedVersion': '1.2.4',
#   'reviewId': '085b34e4-e78d-4fbf-9f56-5314db470575',
#   'score': 3,
#   'thumbsUpCount': 8,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTte9_l8hiotAM3JMiNXV4pJyIg7dFfCVOAd9QGJPAP5s=mo',
#   'userName': 'Bujji Phanikiran'},
#  {'at': datetime.datetime(2022, 7, 20, 21, 2, 8),
#   'content': 'Trying to use for the first time. So far so good. But just '
#              'wondering how come the app does not provide a step to include '
#              'past years loss to adjust against current years gains? Am I '
#              'missing any module in the app ? Please guide. Thank you.',
#   'repliedAt': datetime.datetime(2022, 7, 20, 21, 27, 27),
#   'replyContent': 'Hey there! Nachiketa here, the developer on glyde. We '
#                   'currently support Brought Forward Loss via Autofill on '
#                   'Incomes on your ITR summary. We are also constantly adding '
#                   'new features to help users like yourself add some points '
#                   'manually. If you need any more help, you can drop us an '
#                   'email at help@quicko.com',
#   'reviewCreatedVersion': '2.1.8',
#   'reviewId': 'fa04ce8f-639b-46c6-a889-52bb87ddca20',
#   'score': 3,
#   'thumbsUpCount': 35,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdb4VK0Lafx640JUaaUu0o4nX99DM0a7mbxaP7GqWnb=mo',
#   'userName': 'plate wireindia'},
#  {'at': datetime.datetime(2023, 7, 8, 10, 29, 40),
#   'content': 'best app for itr file',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': '8c8b246b-d3f0-4d59-9371-c72e5595cf13',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT7zKBSR3KEsW8KQu2mqEe09wN7EqYhTFkwdgVBPn4zf_U',
#   'userName': 'Rikesh Ojha'},
#  {'at': datetime.datetime(2023, 7, 12, 18, 36, 37),
#   'content': 'good and helpful',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': '46774115-feef-4628-929e-a3526e938c6e',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTzctANOo3lRaRPzt0zt84ZnwlotdpM9EV-czSP_hFq2mo',
#   'userName': 'Virendra Singh'},
#  {'at': datetime.datetime(2021, 12, 26, 9, 14, 13),
#   'content': "Scrap, annoying , nothing is happening after entering pan , it's "
#              'simply says Something went wrong , we are working , report of '
#              "the bug has been submitted , next day it's ask you update the "
#              "app , if you try to update it won't update it just says "
#              'downloading and intalling it breaks again it says please udate '
#              "samething will be in loop in won't allow you exit of the app too "
#              'annoying, waste of time , I believe this app has been deployed '
#              'to collect pan details only nothing else ,scrap',
#   'repliedAt': datetime.datetime(2021, 12, 27, 19, 59, 48),
#   'replyContent': 'Hey Suresh! We are sorry for the inconvenience that was '
#                   'caused. The updates we push ensure that users get the best '
#                   'possible experience using the app. We have identified the '
#                   'issue that you might be facing and have already worked out '
#                   'a fix for the same. For any further assistance, you can '
#                   'reach out to us at help@quicko.com',
#   'reviewCreatedVersion': '1.2.1',
#   'reviewId': '92831400-682e-4d09-96b5-fe626a198a1d',
#   'score': 1,
#   'thumbsUpCount': 19,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRkozjUguoaqp4iuZynKeqnw6Hhk7ysckSABrtwS03ZdVw',
#   'userName': 'Suresh Kumar Kollapuri'},
#  {'at': datetime.datetime(2022, 7, 27, 20, 35, 44),
#   'content': 'Amazing user interface, all details were auto populated, filing '
#              "tax couldn't have been easier. Kudos to the development team.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.2.1',
#   'reviewId': '44c24b65-6746-4bc6-ab2b-e96931f05247',
#   'score': 5,
#   'thumbsUpCount': 12,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfVG7n5E4FdYyaZwTu-kopckNgFaFVgdplke2dsBZ1_=mo',
#   'userName': 'Shreyas Ullal'},
#  {'at': datetime.datetime(2021, 12, 23, 22, 50, 15),
#   'content': "Never thought filing tax would be so easy. First time I didn't "
#              'on my own. Amazing UI experience and anyone can understand '
#              'easily.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '8594162d-d9e4-40a2-ab42-b96323777b35',
#   'score': 5,
#   'thumbsUpCount': 6,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQOlLLaP_bM-jByOEYh8IpjrlFSjclFSY_wDFsaVyPu4JE5',
#   'userName': 'Dinesh Kumar'},
#  {'at': datetime.datetime(2021, 12, 23, 12, 28, 14),
#   'content': "Doesn't proceed after entering PAN itself, showing loader for "
#              'very long and then again continue button. Need fast and smooth '
#              'experience.',
#   'repliedAt': datetime.datetime(2021, 12, 24, 15, 53, 17),
#   'replyContent': "Hi Yaseen, we are sorry - our first impression wasn't that "
#                   'great. Some of you faced issues while signing up & others '
#                   'while onboarding. We are back up now. Would love for you to '
#                   'try it again. If we are able to meet your expectations, do '
#                   'give us a thumbs up :)',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '18c6a3f7-35da-4241-bd68-549e7787d12d',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTaIOiUnt30lJev8DSHP1A4BMZQzX9czG8P_zIPsx7Lbdc',
#   'userName': 'Yaseen Nadaf'},
#  {'at': datetime.datetime(2021, 12, 23, 12, 36, 52),
#   'content': 'Do not put your app on production if your app is not ready to '
#              'handle the users. Put it in beta and test it properly before '
#              "making it live. It's stucked at the pan page, not going forward. "
#              "At least give a message to the users, why it's failing. Break "
#              'with a scream is always better than silent break.',
#   'repliedAt': datetime.datetime(2021, 12, 24, 18, 40, 33),
#   'replyContent': "Hey, we are sorry, our first impression wasn't that great. "
#                   'Some of you faced issues while signing up & others while '
#                   'onboarding. We are back up now. Would love for you to try '
#                   'it again. If we are able to meet your expectations, do give '
#                   'us a thumbs up :)',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '4721bec9-41ea-404d-b998-19cc7d5ee655',
#   'score': 1,
#   'thumbsUpCount': 17,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteHVdOWIe17iRC_CepxhFyOszrHNpmixYgISNk6Z4MK=mo',
#   'userName': 'Freaky Developers'},
#  {'at': datetime.datetime(2022, 9, 14, 0, 37, 25),
#   'content': "Amazing app. Can't wait to checkout it's competitors. I want the "
#              'app to be able to import bank statement and analyse my income. '
#              'Have no confidence that I will ever earn enough to pay income '
#              'tax.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.2.5',
#   'reviewId': 'e6cd29c0-88c0-48fd-b9dd-536ef77295b9',
#   'score': 5,
#   'thumbsUpCount': 4,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTNwlxM9rIajrGnzDSCmvVoGHvXUNtH0Uby5EkDpZyMwUiI',
#   'userName': 'S K Puneeth Kumar'},
#  {'at': datetime.datetime(2022, 7, 21, 18, 19, 49),
#   'content': 'Excellent app for filing income tax. All field are auto filled '
#              'by the app. Fetching all trading data within a fraction of time. '
#              'I am impressed with this application. Thank you team glyde for '
#              'making e-filing a cake walk.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.1.8',
#   'reviewId': 'd0c51687-6fd2-4a87-9e4c-af16d9f9a9a0',
#   'score': 5,
#   'thumbsUpCount': 13,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfjKFCb7NeyYxh376L-LX_8XTJMlc8vd9_2zT9nDn-c=mo',
#   'userName': 'DEEPAK KUMAR SWAIN'},
#  {'at': datetime.datetime(2021, 12, 23, 13, 39, 17),
#   'content': 'I am just starting the application and it took multiple attempts '
#              'to signup with email or Google account. Now it is not accepting '
#              'my PAN details and says "let\'s try again". I have tried '
#              'multiple times. Not at all satisfied with the application.',
#   'repliedAt': datetime.datetime(2021, 12, 23, 13, 43, 51),
#   'replyContent': 'Hello Niteshkumar! Thanks for checking out the app. Looks '
#                   'like are servers got a bit too hot from all the attention '
#                   '😅. You can try again in some time.',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '715f67b6-9e02-48b4-9ee4-dbca875e6a93',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQOyPYzEnLv1nMwbUnmVAWYg15NKN35OK1Wr1VXAZd1ys0Z',
#   'userName': 'Niteshkumar Choudhari'},
#  {'at': datetime.datetime(2021, 12, 29, 9, 19, 38),
#   'content': 'One of the coolest UI and easy-to-use application. It not only '
#              'helps computing taxes and filing ITR in minutes but also lets '
#              'you verify the same within seconds.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.2',
#   'reviewId': '5c53a92d-4afd-4ef4-968b-7889d84818a4',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSxiA-62FUjBJnsZay51AYFdxSMlYlq8NJGHeDZYrnxNE5f',
#   'userName': 'Rishabh Bhatia'},
#  {'at': datetime.datetime(2021, 12, 24, 14, 12, 17),
#   'content': 'AD video looks promising but am stuck right on page1, when i '
#              "enter my PAN, It doesn't let me goto next step, noway to reach "
#              'support there too apart from writing a review question on '
#              'playstore hoping support looks in. Update: resolution from '
#              'support, mentioning load, seems working now, still exploring',
#   'repliedAt': datetime.datetime(2021, 12, 23, 12, 49, 16),
#   'replyContent': 'Hey Vignesh! Thanks for checking the app out. Our servers '
#                   'are running hot with taxpayers like you wanting to check '
#                   'out the app. Please try again some time later.',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '7e57826c-5ed6-4509-a583-ae7a57811454',
#   'score': 2,
#   'thumbsUpCount': 7,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtekzB6YDp2jU1oKhvPPXm6xDz5GnJnjrJQt-q8rG7v8=mo',
#   'userName': 'Vignesh'},
#  {'at': datetime.datetime(2021, 12, 23, 12, 35, 42),
#   'content': 'Improve your App There are to many bugs. I have tried 20 time to '
#              'just login. Once successfully logged And after entering PAN the '
#              'app is not going further.',
#   'repliedAt': datetime.datetime(2021, 12, 23, 12, 37, 1),
#   'replyContent': 'Hey Sabir! Thanks for checking the app out. Our servers are '
#                   'running hot with taxpayers like you wanting to check out '
#                   'the app. You can try again in some time.',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': 'e38d987d-748f-4e3c-ab71-4860889f85f8',
#   'score': 1,
#   'thumbsUpCount': 5,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMR3BwAphZr4THuLJJITR_DG0EetflN279LgeI1s9Nur0g',
#   'userName': 'Sabir Khorajiya'},
#  {'at': datetime.datetime(2021, 12, 26, 12, 55, 26),
#   'content': "closes/crashes/throws errors often. Super early stage but I'm "
#              'super excited for what it CAN BE.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.1',
#   'reviewId': '0c1a01c5-1135-43b6-a6fa-a61d81d9e9a0',
#   'score': 3,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQDEgG4SL7GE0oUNdFwub71Qqrk44JQ5_DAN4HkSwVV_wE',
#   'userName': 'Kirubhas Shankar'},
#  {'at': datetime.datetime(2021, 12, 23, 12, 32, 52),
#   'content': 'App has too many bugs 1. It takes a lot of time to even register '
#              '2. After n unsuccessful attempts when it finally registers you '
#              'then again it takes forever to continue after entering PAN '
#              'details Please look into it ASAP',
#   'repliedAt': datetime.datetime(2021, 12, 24, 13, 23, 41),
#   'replyContent': 'Hey Akshay, our servers got overwhelmed with all the '
#                   'attention we had gotten suddenly. We are sorry, our first '
#                   "impression wasn't gerat. Some of you faced issues while "
#                   'signup and other while onboarding. We are back up now. '
#                   'Would love for you to give it another try and let us know '
#                   'if we were able to meet your expectations :)',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': 'd918b73f-96af-4597-be01-79d003317c09',
#   'score': 1,
#   'thumbsUpCount': 6,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMThh36SRTu1AXiL1x7NLP3gptjweIv6FOlmaXVZm2NEhFI',
#   'userName': 'Akshay Mundada'},
#  {'at': datetime.datetime(2021, 12, 23, 14, 39, 45),
#   'content': "Can't pass onboarding. First error by snging in with Google, "
#              "second error when entering PAN. Wonder why it's backed by "
#              'zerodha. And they deleted my review once. So here it is again.',
#   'repliedAt': datetime.datetime(2021, 12, 23, 19, 7, 8),
#   'replyContent': 'Hi Akash, We are sorry for the inconvenience caused. We '
#                   'have addressed all the issues and are back up! Do consider '
#                   'giving it another shot.',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': 'fe3c2544-cf87-4c29-b087-dc576099d32e',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTzxVxJAjfxJaq4xPWrNH-TkE0iQqcmdAERcGcGRfIcwPaA',
#   'userName': 'Akash Verma'},
#  {'at': datetime.datetime(2022, 4, 29, 20, 39, 48),
#   'content': "It is useless app,doesn't let itr filing and worst is they don't "
#              "let deactivate tax payer in case i don't want to use this app. "
#              'Forcedul blackmail, use our app or else forget the data which is '
#              'stored with them.',
#   'repliedAt': datetime.datetime(2022, 5, 2, 10, 23, 19),
#   'replyContent': 'Hey Naveen. Nachiketa here, the developer on glyde. The '
#                   'option to deactivate the taxpayer is in the "You" section '
#                   'of the app, easily accessible to anyone. Also, we take '
#                   'utmost care in managing your data in accordance with out '
#                   'privacy policy. We would love to sort any more confusion '
#                   'you may have. You can reach out to us via help@quicko.com!',
#   'reviewCreatedVersion': '1.2.4',
#   'reviewId': 'cd7df75d-f5f1-4b16-8326-0508d8807f16',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTc_kHUQpMIx1_9U-Vk_7bTqpbx3c_7vch92NeetCOveHI',
#   'userName': 'Naveen Kulkarni'},
#  {'at': datetime.datetime(2021, 12, 23, 13, 4, 39),
#   'content': 'The app is very slow. I entered my PAN id but its not going '
#              'further. Not upto the expectation. I just rushed to install and '
#              'use the app afterall Zerodha is pushing marketing notifications '
#              'for it but just the experience is just frustration. Even the '
#              'website Quicko is too slow. And other starnge thing I noticed, '
#              'when we search this app, it shows 4.5 rating but when we enter '
#              'the app page on the playstore it shows 2.3 rating. Is it a '
#              'joke🤣?',
#   'repliedAt': datetime.datetime(2021, 12, 23, 19, 50, 50),
#   'replyContent': 'Hey Jayaprakash! We stumbled a bit form all the attention '
#                   'but we are now up and running at full steam! You can glyde '
#                   'through your taxes without any issue.',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '1a560ff6-627a-4402-b940-55303e189d2e',
#   'score': 1,
#   'thumbsUpCount': 6,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQj6yO6N-YS19duPFSYnSFpBE27myQvd7ulV7kea_tf-C0',
#   'userName': 'Jayaprakash Lokhande'},
#  {'at': datetime.datetime(2022, 5, 6, 13, 4, 10),
#   'content': 'App is great, but it should have option to upload form-16 like '
#              'clear tax, it will save lot of manual entries by the user and '
#              'ensures accuracy.',
#   'repliedAt': datetime.datetime(2022, 5, 6, 13, 23, 36),
#   'replyContent': 'Hello Sainath, Nachiketa here. Thanks for suggestion!  We '
#                   'actually do support Form-16 upload when you choose to add '
#                   "your salary. You can tap on 'Add' Income and pick Salary. "
#                   "Then you'd have an option to either add Upload Form-16 or "
#                   'add manually. \n'
#                   '\n'
#                   "We'd love to address any other questions you might have, "
#                   'just ping on help@quicko.com!',
#   'reviewCreatedVersion': '1.3.0',
#   'reviewId': '62a75083-2162-4fa7-85ea-9dfd0da52677',
#   'score': 3,
#   'thumbsUpCount': 7,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRM1LNvpRSDfAGFMJ_LNhjgZote0lhtiNbMBZOY2Y9NZuGp',
#   'userName': 'Sainath Gupta'},
#  {'at': datetime.datetime(2021, 12, 23, 17, 22, 5),
#   'content': "So I've been postponing my tax filing for months and 'glyde' "
#              'does it in less than 5 minutes. It auto fetched all my returns '
#              "from stocks from the broker's app directly. Highly Recommended!",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': 'd81c2aa8-9658-4183-860b-46e5ea70e36c',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQ0i4i9eLWcRZsFbtaW6afGF2V2FIcqOVFW19dUSQPlHp0',
#   'userName': 'Pranav Bargotra'},
#  {'at': datetime.datetime(2021, 12, 23, 15, 39, 2),
#   'content': 'Whenever i try to register on this app and fill v PAN number, it '
#              'always say that this is wrong number please fill correct pan '
#              "number. I tried using my family's pan number but probelm remains "
#              'the same. Not worth when u cant even register on this app. Zero '
#              'star.',
#   'repliedAt': datetime.datetime(2021, 12, 24, 17, 38, 24),
#   'replyContent': 'Hey Ashpreet, we were experiencing increased traffic (and '
#                   'attention) on our servers. We are resolving it to '
#                   'accommodate taxpayers like you. We are sorry for the poor '
#                   'experience you had. Can you please give it another shot? '
#                   'and let us know how we did this time around :)\n',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': 'e6036cbd-9443-44a2-856a-1cf6f808399e',
#   'score': 1,
#   'thumbsUpCount': 20,
# ...
#   'score': 5,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtf0IdX_ek8Psyrt2tCueFEhnm0Emgn68w6fSbh5sPc=mo',
#   'userName': 'Lokesh Dandagavhal'},
#  {'at': datetime.datetime(2022, 7, 31, 9, 10, 30),
#   'content': 'superp',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.2.3',
#   'reviewId': '0d9dcc51-e97f-49e3-8605-daf452c8db17',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTgqHCfGRYJCwsBej2kCWyghH4bKOKO_WO_AsFz-wSeZho',
#   'userName': 'Vikas Gupta'},
#  {'at': datetime.datetime(2022, 7, 26, 5, 52, 18),
#   'content': 'good',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.2.1',
#   'reviewId': '5ada8584-51f4-4100-b36f-d6018e795261',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRLwia6d0T--dVbdYsbJds0fsa3Z0N07Fu8RpxsvKF5RQ',
#   'userName': 'LEELAVATHI PERIYASAMY'},
#  {'at': datetime.datetime(2022, 7, 24, 18, 5, 36),
#   'content': 'excellent',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.1.8',
#   'reviewId': 'dd8e6c41-f57b-4057-b8ea-9ce0ef856e10',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcJdgCiEbCFzMyiVGBJmWcFYZQaAFn7kgQhWHv5UtuJ=mo',
#   'userName': 'P.L.DRUGS MITHANPURA'},
#  {'at': datetime.datetime(2022, 7, 22, 17, 58, 26),
#   'content': 'Nil',
#   'repliedAt': datetime.datetime(2022, 7, 22, 18, 1, 28),
#   'replyContent': 'Hey there. We would love to help you out with your '
#                   'situation if you could kindly let us know any challenges '
#                   'you may be facing. You can drop us an email at '
#                   'help@quicko.com',
#   'reviewCreatedVersion': '2.1.8',
#   'reviewId': '0675558d-9751-46ce-85ef-77eac0ba4b2c',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSDVj_i74DvhDmjrh6RarmIvvb1QhPLW6fkvyD-NLgOvw',
#   'userName': 'k.vijaya doss'},
#  {'at': datetime.datetime(2022, 7, 14, 19, 49, 47),
#   'content': 'ekdum jhaaaakaaaaasssss app hai ...sab download karo',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.1.5',
#   'reviewId': '2734edc6-e73a-45d3-a414-c93214f9d986',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQh7f7E0zTQsUOTY0a-mzfpZ0yjZOfLzqFmrVv_Qo3W8w',
#   'userName': 'SURAJ'},
#  {'at': datetime.datetime(2022, 5, 16, 17, 23, 53),
#   'content': 'Ismein kuch interesting features Nahin Hai Jo is application ko '
#              'use karu',
#   'repliedAt': datetime.datetime(2022, 1, 21, 11, 40, 18),
#   'replyContent': 'Hey Govind. Nachiketa here, the developer on glyde. We have '
#                   'a ton of features to help you file your taxes on the app '
#                   'right now with more exciting features in the pipeline. You '
#                   'can follow our social channels (@HowToQuicko) to stay '
#                   'updated about cool new features coming up on the app.',
#   'reviewCreatedVersion': '1.3.2',
#   'reviewId': 'c00168cb-4b72-4477-9eba-d0e3c11af030',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT9XdBE7-EhX80A5g4FNZd7SqPQinqW9pnr11aJI2y-9Q',
#   'userName': 'Govind Patel'},
#  {'at': datetime.datetime(2022, 4, 13, 10, 8, 39),
#   'content': 'Not working',
#   'repliedAt': datetime.datetime(2022, 7, 24, 18, 37, 25),
#   'replyContent': 'Hey Sanjeeb. We have been working hard to enable all the '
#                   'features that our users love over the past few weeks and '
#                   'now we are proudly helping a bunch of people glyde through '
#                   'their taxes! How about giving us another shot?',
#   'reviewCreatedVersion': '1.2.9',
#   'reviewId': 'd186e6a1-520c-4c05-a0c8-da1936c96f5e',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTrR815dLi7CBYnctr301Y8i7U5RpG2waa3Dg30p56axQ',
#   'userName': 'Sanjeeb Bhowmick'},
#  {'at': datetime.datetime(2022, 1, 14, 11, 49, 34),
#   'content': 'awesome smooth',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.6',
#   'reviewId': '34726239-133e-4aec-bc68-b9551b701a93',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtf4rN6wxPZ9pn5XqE4dE4OysLeiTAAaF-5-f1cU8pdS=mo',
#   'userName': 'Saxena Ashish'},
#  {'at': datetime.datetime(2022, 1, 13, 22, 37, 53),
#   'content': '🤩🔥',
#   'repliedAt': datetime.datetime(2022, 1, 4, 10, 32, 42),
#   'replyContent': 'Hey Siddharth! We are aware of the issue and have already '
#                   'pushed out a fix for it. Rest assured, you ITR has been '
#                   'correctly filed. For any further information, you can reach '
#                   'out to us at help@quicko.com.',
#   'reviewCreatedVersion': '1.2.5',
#   'reviewId': '495b7b03-7d46-4cc8-91dd-4a20f57b7f76',
#   'score': 5,
#   'thumbsUpCount': 10,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTiMtgeHZUzzLtB6kX8OTzbdE6S_eKw2IvHG-jAwwPk_hs',
#   'userName': 'Siddharth Sahu'},
#  {'at': datetime.datetime(2021, 12, 31, 14, 45, 33),
#   'content': '3 min me ITR bhar gaya....wow amazing app loved it',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.4',
#   'reviewId': '45aa29f6-8024-4d08-86cb-751c6a2184fa',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcFeWvLskNtGuS8PhlV6dS7XR1gUPvblyD5C0WDjkNR=mo',
#   'userName': 'Puneet Joshi'},
#  {'at': datetime.datetime(2021, 12, 25, 19, 38, 24),
#   'content': 'Simple. Good.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.1',
#   'reviewId': '40ab02ae-1bb5-4a82-92e9-b39538aba035',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTFm3FwDXK-qLAnWNY0-Jx7i5FWTthqYbs0ChWH8CTyTwo',
#   'userName': 'Venkidu Periasamy'},
#  {'at': datetime.datetime(2021, 12, 27, 21, 29, 41),
#   'content': 'Amazing',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.1',
#   'reviewId': 'fd76f16e-0120-477d-b7ac-437b07c8abf6',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRPnR0mArA9UlfgDrE1ImaZQ4FJkzaQ8IExFXtAdYeiigw',
#   'userName': 'ZAK ENTERTAINMENT'},
#  {'at': datetime.datetime(2021, 12, 27, 0, 45, 17),
#   'content': 'Very poor',
#   'repliedAt': datetime.datetime(2021, 12, 27, 7, 44, 19),
#   'replyContent': 'Hey there. Could you please elaborate on the issue? We '
#                   'would love to hear about your experience with the app and '
#                   'help with any hurdles you might have faced using it.',
#   'reviewCreatedVersion': '1.2.1',
#   'reviewId': '6f7d6af1-0208-411b-a27e-9bda0b1fc6c3',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRKyH5X1fC0mi0YtxiPWEKuCruREARmOOVLD3xKsdTFI_8',
#   'userName': 'Vikash Singh Rawat'},
#  {'at': datetime.datetime(2021, 12, 23, 19, 36, 46),
#   'content': 'phenomenal!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '18d95aa7-e38f-4eeb-9c5e-50654126dda9',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTlUPQKwi8HbdBSjS_V2ZJo4Tz4CnmCXZYhyshl0lNfw_E',
#   'userName': 'Anand Vardhan'},
#  {'at': datetime.datetime(2021, 12, 23, 21, 36, 59),
#   'content': 'Good one 👍',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': 'a7c319e5-4c57-41f0-b70b-f578d03034d9',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMS770T8pXLhUFFm791iaUu9Z3d0W1DLGqOZeT7b22Y3yic',
#   'userName': 'Rahul Meghnani'},
#  {'at': datetime.datetime(2021, 12, 24, 16, 10, 17),
#   'content': 'Issue resolved',
#   'repliedAt': datetime.datetime(2021, 12, 24, 16, 3, 27),
#   'replyContent': 'Hi Abhishek! We hit a few bumps yesterday onboarding a '
#                   'whole bunch of people wanting to try the app out. We have '
#                   'fixed all the issues are back up so do give us another '
#                   'shot!',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '1bb680d1-00ac-4d1c-a598-f3eb60007c1d',
#   'score': 4,
#   'thumbsUpCount': 6,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRV2wfkXcalXvEMZOa8gobqJxGJFD22WOqCOoHmBL3bPb0',
#   'userName': 'Abhishek Bhadoriya'},
#  {'at': datetime.datetime(2021, 12, 23, 14, 59, 4),
#   'content': 'Worst app',
#   'repliedAt': datetime.datetime(2021, 12, 24, 17, 56, 28),
#   'replyContent': 'Hey. We are sorry for the less-than-stellar experience you '
#                   'had with our app yesterday. Our servers got a bit too hot '
#                   'from all the attention we got. We have since addressed the '
#                   'issue and are back up better than ever. Hope you give us '
#                   'another shot and tell us how we did!',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': 'd5624cdb-19c2-4a98-806e-0fa97a9c3fa0',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT6BSptXmyWBnHwXHp63NNstIbHhHsWx-u3WWuWHSo-_dqC',
#   'userName': 'Pandiri Venugopal'},
#  {'at': datetime.datetime(2021, 12, 23, 22, 45, 54),
#   'content': 'looks promising.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '5024147e-37c8-404b-b859-bfc83a80a640',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRO4oRcreY20PUgNq3MZQTnlBtRh_dvuvQ2Y6-E8f94q5E',
#   'userName': 'Jatin Rana'},
#  {'at': datetime.datetime(2021, 12, 23, 17, 35, 23),
#   'content': 'good',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '32538919-bdba-4e0c-99b3-75f32e7add65',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcNYYzd7zkQYQVbWORfvMd8-tDL4lkJAcaTK89iPNlIXGA=mo',
#   'userName': 'Madhu Sagar'},
#  {'at': datetime.datetime(2021, 12, 23, 21, 51, 21),
#   'content': 'nice',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '4ad94781-004b-4fe6-80ca-4925456cf17a',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQV3ww69yV0hnc6pj_iP9KyHfHebjtaY04LSOqmM7BdsI8',
#   'userName': 'Krishna Giri'},
#  {'at': datetime.datetime(2021, 12, 23, 12, 24, 32),
#   'content': 'Not working',
#   'repliedAt': datetime.datetime(2021, 12, 23, 20, 9, 9),
#   'replyContent': 'Hi Pramod! Our servers got a bit too hot from all taxpayers '
#                   'like you trying to file their taxes. We are up and running, '
#                   'ready to glyde now. Would love for you to try again and let '
#                   'us know how we did :)\n'
#                   '\n',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': 'c1c04a30-1b08-4728-9137-05337c94a2dd',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQbrSVu-zvotPOZEt7La5CYlY3WfZFjFzAbX2uCs5qR68DI',
#   'userName': 'PMIspat'},
#  {'at': datetime.datetime(2021, 12, 23, 12, 41, 40),
#   'content': 'Not working',
#   'repliedAt': datetime.datetime(2021, 12, 24, 18, 4, 52),
#   'replyContent': 'Hi Srinivas, We were facing downtimes with our server but '
#                   'we are back up and running now. Ready to serve you. '
#                   'Requesting you to try again now :)\n',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': 'c8e34225-372a-45be-855a-f3e1567debca',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSkThaHzCkgDrxRJpFXKbTcEYQXikoRCGG5PWm0usUKFzk',
#   'userName': 'Srinivas Kunchala'},
#  {'at': datetime.datetime(2021, 12, 23, 12, 23, 12),
#   'content': 'Not working',
#   'repliedAt': datetime.datetime(2021, 12, 23, 17, 52, 27),
#   'replyContent': 'Hey Valan, we got a lot of attention and servers were '
#                   'experiencing some downtime. glyde is up and even stronger '
#                   'now. Can you give it another try again? And show us some '
#                   'love if we met your expectations :)',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '1f8c9fdc-5d4e-4059-a6cf-638f28a98490',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfO9MGp2GmUUELto9zmeI8_MYbxMCMaqwcX8ReKXBQK=mo',
#   'userName': 'valan solucis'},
#  {'at': datetime.datetime(2021, 12, 23, 13, 10, 39),
#   'content': 'Not working',
#   'repliedAt': datetime.datetime(2021, 12, 23, 17, 46, 26),
#   'replyContent': 'Hey, our servers were hot accomodating taxpayers like you '
#                   'trying to use glyde. We are now up and running. Can you '
#                   'give it another shot? And, give us a shout if we met your '
#                   'expectations? :)',
#   'reviewCreatedVersion': '1.2.0',
#   'reviewId': '3d12a5e8-c515-4dbf-b5e4-14a882f81d3e',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtd2AdKCgSgfKZj6G9TlM0yY8CmxtXfmbCcdF3OveaR5=mo',
#   'userName': 'everything jpaarmi'},
#  {'at': datetime.datetime(2021, 12, 10, 19, 32, 22),
#   'content': 'Verynice thankyou',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '0.1.8',
#   'reviewId': '59746622-e548-485f-bfbd-7c620792d0f4',
#   'score': 3,
#   'thumbsUpCount': 6,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMS0MaFSSsPVNl4glN0wOa49p8G9jO12_4O3Bdai_LXtdA',
#   'userName': 'Vijai Paraulia'},
#  {'at': datetime.datetime(2021, 12, 30, 9, 28, 13),
#   'content': 'Great work.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '0.1.1',
#   'reviewId': '136faf54-7ff3-4693-93ea-53510543aa6c',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTL9bQ_hbL1PJOOyyFkYUGFyUmMsyCfsrFjANjL8YZvA7lG',
#   'userName': 'Jaydevsinh Sonagara'},
#  {'at': datetime.datetime(2021, 11, 26, 11, 5, 14),
#   'content': 'Perfect👍',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '0.1.0',
#   'reviewId': '40519adb-0768-4bc9-8cf8-a388fc3c8b85',
#   'score': 5,
#   'thumbsUpCount': 7,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcXe3zqH3x_HHbEULtIDVUfzIx4itxM08lvuVRiLYSW=mo',
#   'userName': 'taruna jhala'},
#  {'at': datetime.datetime(2021, 12, 23, 14, 34, 54),
#   'content': 'Ye Pan Number check nahi kar pa raha tax kya bharega',
#   'repliedAt': datetime.datetime(2021, 12, 23, 14, 36, 23),
#   'replyContent': 'Hi Tannu! Our servers got a bit too stressed from all '
#                   'taxpayers like you trying to file their taxes. Please try '
#                   'again in some time!',
#   'reviewCreatedVersion': None,
#   'reviewId': 'b92d0bdc-3448-4b07-acaa-826e62ee1568',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfLjk0JT09GodUD7gyg_2rEHbutLcV3W2otfgXsB2ZL=mo',
#   'userName': 'Tannu Gupta'},
#  {'at': datetime.datetime(2022, 1, 8, 6, 12, 9),
#   'content': 'Waist',
#   'repliedAt': datetime.datetime(2022, 1, 8, 8, 31, 15),
#   'replyContent': 'Hey Nitin! Nachiketa here, the developer on glyde. We  '
#                   'would love to help you out with any issue you might me '
#                   'facing. Would you please elaborate on what seems to be the '
#                   'problem?',
#   'reviewCreatedVersion': None,
#   'reviewId': '4c3763d0-1818-42b2-8da2-0efa234262d2',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfsju5AUZ4_50_EagG3csbO3tkhav6b1DHaaLSjI8Tl=mo',
#   'userName': 'Nitin Khairnar'},
#  {'at': datetime.datetime(2022, 7, 21, 2, 33, 21),
#   'content': 'Nice',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': '440e73f2-2849-4156-89c1-ddfe3448a7fc',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQB4BH_kERXRLfStIzCitC05sJB6AUHswgpP_cLYk1_Ytc',
#   'userName': 'SAURAV SINHA'}]

# %%
# writing the json file to csv
import csv

csv_file = 'reviews.csv'

fields = result[0].keys()

with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fields)

    # Write header row
    writer.writeheader()

    # Write data rows
    for row in result:
        writer.writerow(row)
