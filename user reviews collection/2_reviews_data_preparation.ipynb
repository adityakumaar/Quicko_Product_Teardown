# %% [markdown]
# ## Preparation of Ratings and Sentiments Dataset for Analysis

# %%
# importing required libraries
import pandas as pd
import json

# %%
# importing the reviews CSV file
reviews_df = pd.read_csv("reviews.csv")

# %%
# displaying the top 5 rows of the reviews CSV file
reviews_df.head()
# Out:
#                                reviewId                  userName  \
# 0  9963b39f-a553-4556-80d4-e416589a765d               SANJOY JANA
# 1  a05c6113-d5ad-4194-ac07-95f6a8b8c4b3  Vijayakumar Kulandaivelu
# 2  d082e51c-5018-41dd-bbf5-1a313596db82     Ritupurn jain (Rittu)
# 3  a5e64eaa-1b73-407e-bbf2-68cb49072037              Abhay Jadoun
# 4  a1b7411b-dbec-4c31-9ca1-dc65d4a9684d       Shivakumar pandrala
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a/AAcHTt...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                              content  score  thumbsUpCount  \
# 0  Easy and convenience. Anyone can easily fill i...      5              0
# 1                                          Awesome!!      5              0
# 2    marvelous great experience soooooooo smooooooth      5              0
# 3  Wazirx india crypto platform is not available....      1              0
# 4  App is good and simple but not showing angel o...      5              0
#
#   reviewCreatedVersion                at  \
# 0                2.6.2  24-07-2023 19:20
# 1                2.6.2  24-07-2023 13:26
# 2                2.6.2  24-07-2023 12:47
# 3                2.6.2  24-07-2023 10:30
# 4                2.6.2  24-07-2023 07:35
#
#                                         replyContent         repliedAt
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3  Hey Abhay, Nachiketa here. I'm the developer o...  24-07-2023 11:36
# 4  Hey there! AngelOne integration is now live on...  24-07-2023 21:05

# %% [markdown]
# ---
# ### Part 1: Deleting the personal information of users

# %%
# deleting the column containg Personal Information
columns_to_drop = ["reviewId", "userName", "userImage"]
reviews_df = reviews_df.drop(columns=columns_to_drop)

# %%
# displaying the top 5 rows of modified dataframe
reviews_df.head()
# Out:
#                                              content  score  thumbsUpCount  \
# 0  Easy and convenience. Anyone can easily fill i...      5              0
# 1                                          Awesome!!      5              0
# 2    marvelous great experience soooooooo smooooooth      5              0
# 3  Wazirx india crypto platform is not available....      1              0
# 4  App is good and simple but not showing angel o...      5              0
#
#   reviewCreatedVersion                at  \
# 0                2.6.2  24-07-2023 19:20
# 1                2.6.2  24-07-2023 13:26
# 2                2.6.2  24-07-2023 12:47
# 3                2.6.2  24-07-2023 10:30
# 4                2.6.2  24-07-2023 07:35
#
#                                         replyContent         repliedAt
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3  Hey Abhay, Nachiketa here. I'm the developer o...  24-07-2023 11:36
# 4  Hey there! AngelOne integration is now live on...  24-07-2023 21:05

# %% [markdown]
# ---
# ### Part 2: Sentiment analysis of user reviews thorugh Language Model and Prompt Engineering

# %%
# importing the transformers library to use the HuggingFace NLP model
from transformers import pipeline

# %%
# creating a pipeline for analysing sentiment of each user review
sentiment_pipeline = pipeline("text-classification", model="nlptown/bert-base-multilingual-uncased-sentiment")
# Out:
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
# sample sentiment analysis
review_comment = ["App is good and simple but not showing angel one broker"]
sentiment_pipeline(review_comment)
# Out:
# [{'label': '3 stars', 'score': 0.3997366428375244}]

# %% [markdown]
# Note:
#
# <table align="left">
#   <thead>
#     <tr>
#       <th>Rating</th>
#       <th>Label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5, 4 stars</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <td>3 stars</td>
#       <td>Neutral</td>
#     </tr>
#     <tr>
#       <td>2, 1 stars</td>
#       <td>Negative</td>
#     </tr>
#   </tbody>
# </table>

# %%
# sentiment of all user reviews
for index, row in reviews_df.iterrows():
    review_comment = row['content']
    print("Review comment: ",review_comment)
    print("Sentiment     : ",sentiment_pipeline(review_comment))
# Out:
# Review comment:  Easy and convenience. Anyone can easily fill itr at here.
# Sentiment     :  [{'label': '5 stars', 'score': 0.6665805578231812}]
# Review comment:  Awesome!!
# Sentiment     :  [{'label': '5 stars', 'score': 0.8769167065620422}]
# Review comment:  marvelous great experience soooooooo smooooooth
# Sentiment     :  [{'label': '5 stars', 'score': 0.8367269039154053}]
# Review comment:  Wazirx india crypto platform is not available. Please add it. You will get more and more users on this platform.
# Sentiment     :  [{'label': '1 star', 'score': 0.3641238808631897}]
# Review comment:  App is good and simple but not showing angel one broker
# Sentiment     :  [{'label': '3 stars', 'score': 0.3997366428375244}]
# Review comment:  Other things are fine, but it was showing me 8000 tax when i was liable for 0, cleartax did job pretty well!
# Sentiment     :  [{'label': '3 stars', 'score': 0.4484536349773407}]
# Review comment:  it's best App to file itr
# Sentiment     :  [{'label': '5 stars', 'score': 0.5438485741615295}]
# Review comment:  ITR filing made dead easy
# Sentiment     :  [{'label': '1 star', 'score': 0.48022183775901794}]
# Review comment:  Fantastic app
# Sentiment     :  [{'label': '5 stars', 'score': 0.8146355152130127}]
# Review comment:  excellent
# Sentiment     :  [{'label': '5 stars', 'score': 0.8669129014015198}]
# Review comment:  Loved it
# Sentiment     :  [{'label': '5 stars', 'score': 0.6379151344299316}]
# Review comment:  Amazingly simple and intuitive
# Sentiment     :  [{'label': '5 stars', 'score': 0.8875816464424133}]
# Review comment:  very good
# Sentiment     :  [{'label': '5 stars', 'score': 0.5479444861412048}]
# Review comment:  it was really great experience..with in short span done..
# Sentiment     :  [{'label': '5 stars', 'score': 0.4883631467819214}]
# Review comment:  Nice Application and helpful for file income tax return.....
# Sentiment     :  [{'label': '4 stars', 'score': 0.515525221824646}]
# Review comment:  AngelOne Not in List
# Sentiment     :  [{'label': '1 star', 'score': 0.43716540932655334}]
# Review comment:  Third class app as well as support people with full of attitude, I got wrost experience, once you pay money they will forget you... Wrost experience
# Sentiment     :  [{'label': '5 stars', 'score': 0.37271276116371155}]
# Review comment:  Sir, While file f&o losses from zerodha , it show non speculative loss. But correct one is speculative !
# Sentiment     :  [{'label': '3 stars', 'score': 0.372996985912323}]
# Review comment:  excellent
# Sentiment     :  [{'label': '5 stars', 'score': 0.8669129014015198}]
# Review comment:  Best itr filing application, user friendly, super application.
# Sentiment     :  [{'label': '5 stars', 'score': 0.9034099578857422}]
# Review comment:  extremely friendly and comprehensive
# Sentiment     :  [{'label': '5 stars', 'score': 0.734377384185791}]
# Review comment:  Wow..just Wow app..i was seaching on youtube about Itr3 and it was so difficult..Zerodha recommend me this app n it was magic.. So simple tax filling process..loved it .5 star.. Thanks Glyde and team.. Kudos
# Sentiment     :  [{'label': '5 stars', 'score': 0.8887758851051331}]
# Review comment:  excellent
# Sentiment     :  [{'label': '5 stars', 'score': 0.8669129014015198}]
# Review comment:  very easy
# Sentiment     :  [{'label': '5 stars', 'score': 0.5387366414070129}]
# Review comment:  Very user friendly app. It retrieves most of the data, you need not to key in it again and again.
# Sentiment     :  [{'label': '5 stars', 'score': 0.5766907334327698}]
# Review comment:  very nice
# Sentiment     :  [{'label': '5 stars', 'score': 0.6515334844589233}]
# Review comment:  I took an annual subscription but my broker ICICI securities is not in the app. Moreover there is no arrangement for uploading P/L statement.
# Sentiment     :  [{'label': '1 star', 'score': 0.43660199642181396}]
# Review comment:  Beautifully designed. Super swift
# Sentiment     :  [{'label': '5 stars', 'score': 0.8726432919502258}]
# Review comment:  bbest
# Sentiment     :  [{'label': '5 stars', 'score': 0.2611572742462158}]
# Review comment:  For Zerodha users traded volume is more than 100 ...app is charging amount. It is not fair. Pl see
# Sentiment     :  [{'label': '2 stars', 'score': 0.35015279054641724}]
# Review comment:  awesome, Hassel free
# Sentiment     :  [{'label': '5 stars', 'score': 0.8005624413490295}]
# Review comment:  This is genuine review. I wanted to say thank you glyde. It was really awesome. Only drawback is your app is little confusing. There should be a confirmation button, I was getting confused because I was unware that it automatically saves information. By the way many many thanks to you
# Sentiment     :  [{'label': '4 stars', 'score': 0.7690916657447815}]
# Review comment:  good and helpful
# Sentiment     :  [{'label': '5 stars', 'score': 0.4819522202014923}]
# Review comment:  Absolutely incredible . . Never thought filing would be so easier . .
# Sentiment     :  [{'label': '5 stars', 'score': 0.9123279452323914}]
# Review comment:  This is the best tax filing application. Best interface in quicko website.Its is so easy to understand the terminology of income tax here and filing tax return is so quick .It is highly recommend to use this especially for salaried person.
# Sentiment     :  [{'label': '5 stars', 'score': 0.9361116886138916}]
# Review comment:  Pathetic service. App is ok, but service from the vendor is absolutely pathetic and you won't be able to file your taxes on time as no one responds to your queries and you would be forced to buy Pro Plan.
# Sentiment     :  [{'label': '1 star', 'score': 0.6250942945480347}]
# Review comment:  Thank you so much
# Sentiment     :  [{'label': '5 stars', 'score': 0.759162187576294}]
# Review comment:  so simple
# Sentiment     :  [{'label': '2 stars', 'score': 0.3710624873638153}]
# Review comment:  I kid you not, I really did Glyde through the ITR process! It was my first time... let's see how it goes.
# Sentiment     :  [{'label': '5 stars', 'score': 0.4990110993385315}]
# Review comment:  best app for itr file
# Sentiment     :  [{'label': '5 stars', 'score': 0.8114801645278931}]
# Review comment:  It's user friendly.
# Sentiment     :  [{'label': '4 stars', 'score': 0.46905526518821716}]
# Review comment:  fantastic app
# Sentiment     :  [{'label': '5 stars', 'score': 0.8146355152130127}]
# Review comment:  Awesome app Great app for all users including new user
# Sentiment     :  [{'label': '5 stars', 'score': 0.836195170879364}]
# Review comment:  Very convenient to use
# Sentiment     :  [{'label': '5 stars', 'score': 0.6022850871086121}]
# Review comment:  Since last 7 days error of outage is appearing while submitting file with meagre amount of tax challan. Not able to find any solution
# Sentiment     :  [{'label': '1 star', 'score': 0.7717733979225159}]
# Review comment:  It has never been so easy.
# Sentiment     :  [{'label': '3 stars', 'score': 0.34332242608070374}]
# Review comment:  Application is not working properly while filling the itr and also not able to everify. As you are charging very high as compared to clear tax,so your system should be stable
# Sentiment     :  [{'label': '2 stars', 'score': 0.4927073121070862}]
# Review comment:  Would be great if support for ITR 4 is also added
# Sentiment     :  [{'label': '3 stars', 'score': 0.4598027765750885}]
# Review comment:  Wonderful, you don't need to worry about tax and e-filing if you're using glyde it covers everything you need.
# Sentiment     :  [{'label': '5 stars', 'score': 0.8580580353736877}]
# Review comment:  easy
# Sentiment     :  [{'label': '5 stars', 'score': 0.5379349589347839}]
# Review comment:  Facing error while itr filing
# Sentiment     :  [{'label': '1 star', 'score': 0.44111865758895874}]
# Review comment:  very userfriendly
# Sentiment     :  [{'label': '1 star', 'score': 0.41347837448120117}]
# Review comment:  Angel One Not showing in the broking list
# Sentiment     :  [{'label': '1 star', 'score': 0.47506409883499146}]
# Review comment:  quite smooth except for payment part
# Sentiment     :  [{'label': '4 stars', 'score': 0.4694801867008209}]
# Review comment:  Good One, Easy Tax filing for Share Traders..
# Sentiment     :  [{'label': '4 stars', 'score': 0.6078701019287109}]
# Review comment:  Great App. Super easy tax filing.
# Sentiment     :  [{'label': '5 stars', 'score': 0.8196687698364258}]
# Review comment:  Smooth. fast. beautiful. useful
# Sentiment     :  [{'label': '5 stars', 'score': 0.6279726624488831}]
# Review comment:  App is not opening,It is showing update but already updated and not opening
# Sentiment     :  [{'label': '1 star', 'score': 0.5822308659553528}]
# Review comment:  very nice
# Sentiment     :  [{'label': '5 stars', 'score': 0.6515334844589233}]
# Review comment:  Easy-to-use and hassle-free free experience
# Sentiment     :  [{'label': '4 stars', 'score': 0.46105891466140747}]
# Review comment:  great and very easy app for itr
# Sentiment     :  [{'label': '5 stars', 'score': 0.7573994398117065}]
# Review comment:  Awesome and wonderful app developed. I have never seen this type of advanced app. I was facing acute stress in filing ITR and it has been resolved by login to the GLYDE. Thanks for Glyde team for developing such a wonderful app.
# Sentiment     :  [{'label': '5 stars', 'score': 0.8959237933158875}]
# Review comment:  it just glided
# Sentiment     :  [{'label': '2 stars', 'score': 0.3765648901462555}]
# Review comment:  Angelone is not in broker list . But it is showing in their pro plan benefits. They are fooling the people . They cheated 1401 rs from me . Fraud company .
# Sentiment     :  [{'label': '1 star', 'score': 0.6975002288818359}]
# Review comment:  No proper guidance, what happens after we review? Waiting for last 3 days...no option to efile visible yet as shown in the video. Pathetic. Even the Json downloaded doesnt get uploaded on IT dept portal for e-filing.
# Sentiment     :  [{'label': '1 star', 'score': 0.8121778964996338}]
# Review comment:  Good app. Dumbest customer service. Regret spending 1400₹ for premium
# Sentiment     :  [{'label': '3 stars', 'score': 0.3655748665332794}]
# Review comment:  easy and fast
# Sentiment     :  [{'label': '5 stars', 'score': 0.6533243656158447}]
# Review comment:  Awesome app, it's simplifies taxation for me, need these kind of good apps
# Sentiment     :  [{'label': '5 stars', 'score': 0.7317835688591003}]
# Review comment:  loved the experience! Made taxes so easy. Hopefully the pay part starts working soon
# Sentiment     :  [{'label': '5 stars', 'score': 0.6936805248260498}]
# Review comment:  Extremely helpful app and one-stop solution for all the tax-related issues. Good work!
# Sentiment     :  [{'label': '5 stars', 'score': 0.733465313911438}]
# Review comment:  Amazing app. Never been too easy filing. Filed my entire family's return using the app. Amazing experience!
# Sentiment     :  [{'label': '5 stars', 'score': 0.9370108842849731}]
# Review comment:  Amazing app. I was able to prepare my income tax return in minutes. Also, love the advance tax calculator feature.
# Sentiment     :  [{'label': '5 stars', 'score': 0.9067445993423462}]
# Review comment:  What a fantastic app
# Sentiment     :  [{'label': '5 stars', 'score': 0.9008098244667053}]
# Review comment:  New
# Sentiment     :  [{'label': '5 stars', 'score': 0.4850592017173767}]
# Review comment:  I have download it but unable to see icon on my mobile.
# Sentiment     :  [{'label': '3 stars', 'score': 0.36313024163246155}]
# Review comment:  App is unable to add Paytm Money App, I tried many times today. .... ...
# Sentiment     :  [{'label': '1 star', 'score': 0.47939532995224}]
# Review comment:  Not all options added for tax rebate e.g. no option to avail rebate on interest paid for house loan, children education allowance, principal on home loan etc.
# Sentiment     :  [{'label': '1 star', 'score': 0.34865349531173706}]
# Review comment:  Showing wrong details. Even raise ticket is also not working.
# Sentiment     :  [{'label': '1 star', 'score': 0.8330444097518921}]
# Review comment:  very easy ITR filing
# Sentiment     :  [{'label': '5 stars', 'score': 0.5056120753288269}]
# Review comment:  Amazing App. Saved me a ton of heartache NOT just headache! KUDOS!!
# Sentiment     :  [{'label': '5 stars', 'score': 0.880597710609436}]
# Review comment:  Tax payment is not working
# Sentiment     :  [{'label': '1 star', 'score': 0.6417855620384216}]
# Review comment:  Great app
# Sentiment     :  [{'label': '5 stars', 'score': 0.7560892701148987}]
# Review comment:  Very deficult to operate
# Sentiment     :  [{'label': '1 star', 'score': 0.7884810566902161}]
# Review comment:  Integration with Paytm money is not working with pro plan, have been trying to do it for ages now, the error always says service not available at Paytm money I don't know how long it will not be available.
# Sentiment     :  [{'label': '1 star', 'score': 0.4402058720588684}]
# Review comment:  Not bad
# Sentiment     :  [{'label': '3 stars', 'score': 0.6073219180107117}]
# Review comment:  sexy af
# Sentiment     :  [{'label': '5 stars', 'score': 0.5360609292984009}]
# Review comment:  Amazing app. Can't wait to checkout it's competitors. I want the app to be able to import bank statement and analyse my income. Have no confidence that I will ever earn enough to pay income tax.
# Sentiment     :  [{'label': '5 stars', 'score': 0.8945521116256714}]
# Review comment:  Simple, Accurate and Easy to use. One less thing to worry about.
# Sentiment     :  [{'label': '5 stars', 'score': 0.6040158271789551}]
# Review comment:  Thank you glyde , very nice app 🙏🙏 mera CA ka kharach bacha diya , mujhe English mai likhna nehi ata
# Sentiment     :  [{'label': '5 stars', 'score': 0.5121644139289856}]
# Review comment:  From where I can know tax audit is required or not. You are just providing turnover. Please clarify this.
# Sentiment     :  [{'label': '3 stars', 'score': 0.26476478576660156}]
# Review comment:  Not moving while downloading only 45% downloaded
# Sentiment     :  [{'label': '1 star', 'score': 0.6778972744941711}]
# Review comment:  Challan not generated but amount deducted please let me know what to do
# Sentiment     :  [{'label': '1 star', 'score': 0.3484092354774475}]
# Review comment:  Great...Easy...& Free...
# Sentiment     :  [{'label': '5 stars', 'score': 0.7745519876480103}]
# Review comment:  amazing I have filled my ITR...
# Sentiment     :  [{'label': '5 stars', 'score': 0.9051987528800964}]
# Review comment:  Anyone can do without.. Not providing anything in paid plan.. I feel like I am being robbed.. Nachiket don't tell me where to write.. Just tell me why my one stock broker is not listed and why p&l statement of other broker is not being uploaded.. Why a customer has to wait for everything even after payment of fees
# Sentiment     :  [{'label': '1 star', 'score': 0.8337674736976624}]
# Review comment:  love u kasam se i an wandering here and there to file itr who have knowledge of stock market as well. love u glyde..thx u very much
# Sentiment     :  [{'label': '5 stars', 'score': 0.6991174221038818}]
# Review comment:  superp
# Sentiment     :  [{'label': '5 stars', 'score': 0.730799674987793}]
# Review comment:  easy, no rocket science
# Sentiment     :  [{'label': '5 stars', 'score': 0.2998109757900238}]
# Review comment:  easy to use sulerb
# Sentiment     :  [{'label': '5 stars', 'score': 0.50322026014328}]
# Review comment:  it's damn easy for a person like me .....
# Sentiment     :  [{'label': '3 stars', 'score': 0.2810949981212616}]
# Review comment:  Site is not connected to GROWW app for find broker details.
# Sentiment     :  [{'label': '1 star', 'score': 0.48555323481559753}]
# Review comment:  Good app and fast
# Sentiment     :  [{'label': '4 stars', 'score': 0.512001097202301}]
# Review comment:  Very useful app to file ITR. Data are prefilled no need to check further thanks for the app.
# Sentiment     :  [{'label': '5 stars', 'score': 0.6451135277748108}]
# Review comment:  paid 1401 charges to get Crypto gains reports, but I have to pay cointracker in bulk for the work which can be done by me. Not useful for 1401 paid, glyde should tied up with cointracker for the benefit of its users to access tax reports freely.
# Sentiment     :  [{'label': '3 stars', 'score': 0.39894625544548035}]
# Review comment:  very nice app to e-file return
# Sentiment     :  [{'label': '5 stars', 'score': 0.4626893103122711}]
# Review comment:  super duper easy
# Sentiment     :  [{'label': '5 stars', 'score': 0.772648811340332}]
# Review comment:  super quick. hassle free..it was truly a seamless glyding experience even with capital gains data
# Sentiment     :  [{'label': '5 stars', 'score': 0.6063608527183533}]
# Review comment:  Good
# Sentiment     :  [{'label': '4 stars', 'score': 0.49696317315101624}]
# Review comment:  Not even possible to import pnl statements
# Sentiment     :  [{'label': '1 star', 'score': 0.6061204075813293}]
# Review comment:  jost chill. amazing
# Sentiment     :  [{'label': '5 stars', 'score': 0.8258204460144043}]
# Review comment:  nice
# Sentiment     :  [{'label': '4 stars', 'score': 0.4368409514427185}]
# Review comment:  no clarification need detailed explanation
# Sentiment     :  [{'label': '2 stars', 'score': 0.31704553961753845}]
# Review comment:  Excellent and that too free, Thanks a lot
# Sentiment     :  [{'label': '5 stars', 'score': 0.8438156843185425}]
# Review comment:  Simply Superb
# Sentiment     :  [{'label': '5 stars', 'score': 0.863516092300415}]
# Review comment:  very good
# Sentiment     :  [{'label': '5 stars', 'score': 0.5479444861412048}]
# Review comment:  I upgraded to pro, but I am not able to link groww account with glyde, it says failed to connect. If this was the case why did I have to pay extra to link 2 or more trading account
# Sentiment     :  [{'label': '2 stars', 'score': 0.37979310750961304}]
# Review comment:  The best portal ever! Hats off to the complete team for making an amazing platform for taxes.
# Sentiment     :  [{'label': '5 stars', 'score': 0.970304012298584}]
# Review comment:  Very good app! Filed my ITR with ease!
# Sentiment     :  [{'label': '5 stars', 'score': 0.722965657711029}]
# Review comment:  How to upload mutual fund gains There is no option available
# Sentiment     :  [{'label': '1 star', 'score': 0.23584392666816711}]
# Review comment:  it's just gri
# Sentiment     :  [{'label': '3 stars', 'score': 0.3104424774646759}]
# Review comment:  Great app, the best for tax filing. It's easy, smooth and very quick. Any novice can easily file tax using it. One thing though, the desktop version is not available.
# Sentiment     :  [{'label': '4 stars', 'score': 0.6591968536376953}]
# Review comment:  Not able to submit the ITR
# Sentiment     :  [{'label': '1 star', 'score': 0.5160276889801025}]
# Review comment:  very easy and smooth application for itr e-filing
# Sentiment     :  [{'label': '5 stars', 'score': 0.6212788224220276}]
# Review comment:  Wonderful, fast and free IT interface. Thanks to the Glyde team.
# Sentiment     :  [{'label': '5 stars', 'score': 0.8182325959205627}]
# Review comment:  Amazing user interface, all details were auto populated, filing tax couldn't have been easier. Kudos to the development team.
# Sentiment     :  [{'label': '5 stars', 'score': 0.6979243755340576}]
# Review comment:  Fraud and cheater app. Don't use this app at all. #TimeWaste
# Sentiment     :  [{'label': '1 star', 'score': 0.950478732585907}]
# Review comment:  Best app I have ever used.
# Sentiment     :  [{'label': '5 stars', 'score': 0.9678996205329895}]
# Review comment:  superb ..very easy to file return.
# Sentiment     :  [{'label': '5 stars', 'score': 0.7969107031822205}]
# Review comment:  very easy to file
# Sentiment     :  [{'label': '5 stars', 'score': 0.5690311193466187}]
# Review comment:  good
# Sentiment     :  [{'label': '4 stars', 'score': 0.49696317315101624}]
# Review comment:  Glyde is such a wonderful app. I was struggling with filling my taxes. Even on sites like cleartax, it is so difficult to figure out the right places to enter details. Glyde just made it so smooth. I could figure out the details easily and also prefill the values from ITD. It is the only app who had an auto import feature for Paytm money which made importing investment details a breeze. Also the team has designed a smooth and wonderful UI. Kudos to them! Love this app! ❤️
# Sentiment     :  [{'label': '5 stars', 'score': 0.9430797100067139}]
# Review comment:  really it's a very good tool
# Sentiment     :  [{'label': '5 stars', 'score': 0.5435215830802917}]
# Review comment:  Very good app. But I have one issue. I have received arrear salary of previous 4 years. I have filled 10E form in IT website but in app it doesn't show. Is this app supports 10E form??
# Sentiment     :  [{'label': '4 stars', 'score': 0.4639676809310913}]
# Review comment:  Done in few clicks. Thanks 🙏
# Sentiment     :  [{'label': '4 stars', 'score': 0.3269309401512146}]
# Review comment:  Hassle free ITR filing on Glyde . Simply super.Nice interface. Recommended to all. But no option to file revised returns
# Sentiment     :  [{'label': '3 stars', 'score': 0.33645889163017273}]
# Review comment:  excellent
# Sentiment     :  [{'label': '5 stars', 'score': 0.8669129014015198}]
# Review comment:  This is an update, it's working really fine, making my work really smooth Thank you.
# Sentiment     :  [{'label': '5 stars', 'score': 0.7152023315429688}]
# Review comment:  very less payment options
# Sentiment     :  [{'label': '2 stars', 'score': 0.44272005558013916}]
# Review comment:  very easy to file tax return
# Sentiment     :  [{'label': '5 stars', 'score': 0.29607754945755005}]
# Review comment:  Nil
# Sentiment     :  [{'label': '1 star', 'score': 0.40807950496673584}]
# Review comment:  Where and how to show my 80C deductions? I could not find the column to fill. Not working in a good manner.
# Sentiment     :  [{'label': '2 stars', 'score': 0.4666777551174164}]
# Review comment:  Excellent app for filing income tax. All field are auto filled by the app. Fetching all trading data within a fraction of time. I am impressed with this application. Thank you team glyde for making e-filing a cake walk.
# Sentiment     :  [{'label': '5 stars', 'score': 0.8956014513969421}]
# Review comment:  How much time it take to fetch broker information I tried 3 times still not updated
# Sentiment     :  [{'label': '1 star', 'score': 0.3881080746650696}]
# Review comment:  Equity/mf p&l losses are fetched from zerodha, but i had to fill dividend manually. please improve this.
# Sentiment     :  [{'label': '3 stars', 'score': 0.3293047249317169}]
# Review comment:  WORKS LIKE MAGIC...SMOOTH AS BUTTER
# Sentiment     :  [{'label': '5 stars', 'score': 0.6124262809753418}]
# Review comment:  Nice
# Sentiment     :  [{'label': '4 stars', 'score': 0.4368409514427185}]
# Review comment:  Trying to use for the first time. So far so good. But just wondering how come the app does not provide a step to include past years loss to adjust against current years gains? Am I missing any module in the app ? Please guide. Thank you.
# Sentiment     :  [{'label': '4 stars', 'score': 0.48111188411712646}]
# Review comment:  ekdum jhaaaakaaaaasssss app hai ...sab download karo
# Sentiment     :  [{'label': '1 star', 'score': 0.38873767852783203}]
# Review comment:  easy to use
# Sentiment     :  [{'label': '5 stars', 'score': 0.539100706577301}]
# Review comment:  It's very easy to File Itr, Good app its very friendly app to understand everything
# Sentiment     :  [{'label': '4 stars', 'score': 0.47836145758628845}]
# Review comment:  Smoothly done my itr
# Sentiment     :  [{'label': '5 stars', 'score': 0.5719752311706543}]
# Review comment:  Unable to fetch details from Angel One account.
# Sentiment     :  [{'label': '1 star', 'score': 0.6137378215789795}]
# Review comment:  Unable to cancel existing meet order and support team is not responding
# Sentiment     :  [{'label': '1 star', 'score': 0.5758478045463562}]
# Review comment:  Can i file itr? NO
# Sentiment     :  [{'label': '1 star', 'score': 0.46346238255500793}]
# Review comment:  Every function is in under update progress.... Big wastage of time
# Sentiment     :  [{'label': '1 star', 'score': 0.4834890067577362}]
# Review comment:  Form-16 upload doesn't work.. It says pan not matching, though it's same...
# Sentiment     :  [{'label': '1 star', 'score': 0.4764973819255829}]
# Review comment:  Ismein kuch interesting features Nahin Hai Jo is application ko use karu
# Sentiment     :  [{'label': '4 stars', 'score': 0.36829790472984314}]
# Review comment:  App is great, but it should have option to upload form-16 like clear tax, it will save lot of manual entries by the user and ensures accuracy.
# Sentiment     :  [{'label': '4 stars', 'score': 0.49933069944381714}]
# Review comment:  It is useless app,doesn't let itr filing and worst is they don't let deactivate tax payer in case i don't want to use this app. Forcedul blackmail, use our app or else forget the data which is stored with them.
# Sentiment     :  [{'label': '1 star', 'score': 0.9105933308601379}]
# Review comment:  Not working
# Sentiment     :  [{'label': '1 star', 'score': 0.6374980807304382}]
# Review comment:  Tax begin & stucked there, not processing.
# Sentiment     :  [{'label': '1 star', 'score': 0.6991950869560242}]
# Review comment:  Hi team, I've created an account and later I logged out. Now if i try to login again, it says taxpayer exists and shows me a bug. I've reported the same. Also when the app was accessible, I didnt open the ITR filing part. Infinite loading. Please look into them. Thanks.
# Sentiment     :  [{'label': '1 star', 'score': 0.7037851810455322}]
# Review comment:  It shows its waiting for a renewal for sync service from the ITD, so its not doing anything automatically it gives you an option to do things manually.. which kills the purpose of glyde I feel.. how long would this fix take ? Also once i click manual by mistake now it doesn't revert to automatic sync to ITD...
# Sentiment     :  [{'label': '3 stars', 'score': 0.39543214440345764}]
# Review comment:  awesome smooth
# Sentiment     :  [{'label': '5 stars', 'score': 0.8022410869598389}]
# Review comment:  🤩🔥
# Sentiment     :  [{'label': '5 stars', 'score': 0.3085777759552002}]
# Review comment:  Not working at all. App is just stuck after I enter my Pan Card number. Reloads on continue. That's it
# Sentiment     :  [{'label': '1 star', 'score': 0.7682836055755615}]
# Review comment:  Waist
# Sentiment     :  [{'label': '3 stars', 'score': 0.27643847465515137}]
# Review comment:  A simple tool for complex data.
# Sentiment     :  [{'label': '4 stars', 'score': 0.46372708678245544}]
# Review comment:  Doesn't work. Not able to go past the PAN entry
# Sentiment     :  [{'label': '1 star', 'score': 0.8154259324073792}]
# Review comment:  blogs are not upto date, example cryptocurrency.
# Sentiment     :  [{'label': '1 star', 'score': 0.4139593839645386}]
# Review comment:  After entering pan details, it shows my name saying make sure it’s you. After that nothing happens. No next or something like it either. Tried for 10 days , but nothing happened. No support either.
# Sentiment     :  [{'label': '1 star', 'score': 0.787225067615509}]
# Review comment:  No option to add mutual fund capital gains.
# Sentiment     :  [{'label': '1 star', 'score': 0.5219218134880066}]
# Review comment:  We need integration with Groww.
# Sentiment     :  [{'label': '3 stars', 'score': 0.32422250509262085}]
# Review comment:  Ok finally was able to file my returns. But it was constant checking, updating app numerous times. Hope yhe fixes now will help file taxes easily next year. I'll give a 5 star if the experience next year is smooth. There were a lot of hiccups this year.
# Sentiment     :  [{'label': '4 stars', 'score': 0.6557823419570923}]
# Review comment:  3 min me ITR bhar gaya....wow amazing app loved it
# Sentiment     :  [{'label': '5 stars', 'score': 0.8684694170951843}]
# Review comment:  most of the time coming some error and error resolution can't rectify easily and face too much problem.
# Sentiment     :  [{'label': '2 stars', 'score': 0.48679792881011963}]
# Review comment:  So easy and simple to file ITR using the app. But sometimes will take lot of time to move to next page or to login.
# Sentiment     :  [{'label': '4 stars', 'score': 0.5050586462020874}]
# Review comment:  Fantastic App for ITR filling. Loved the easy interface and smooth functioning. keep it up...
# Sentiment     :  [{'label': '5 stars', 'score': 0.7793866395950317}]
# Review comment:  Not going ahead after entering Pan card no. This issue now resolved for me. Thank you team Quicko.
# Sentiment     :  [{'label': '1 star', 'score': 0.5779610276222229}]
# Review comment:  Super amazing. Pretty quick and easy.
# Sentiment     :  [{'label': '5 stars', 'score': 0.9017399549484253}]
# Review comment:  the app is really great.. 👌..just add option for deduction for educational tution fee payment in 80c
# Sentiment     :  [{'label': '5 stars', 'score': 0.6475976705551147}]
# Review comment:  Problem automatically solved, don't know how. ---------+ After filling all things, on clicking let's file. After filling credentials of income tax account, it shows Account login required error. And comes back 3-4 times. 5 times it solved.
# Sentiment     :  [{'label': '1 star', 'score': 0.5339766144752502}]
# Review comment:  Great work.
# Sentiment     :  [{'label': '5 stars', 'score': 0.7230890393257141}]
# Review comment:  Amazing interface and easy to use
# Sentiment     :  [{'label': '5 stars', 'score': 0.8083924651145935}]
# Review comment:  Filed my first ITR, great experience
# Sentiment     :  [{'label': '5 stars', 'score': 0.7907700538635254}]
# Review comment:  One of the coolest UI and easy-to-use application. It not only helps computing taxes and filing ITR in minutes but also lets you verify the same within seconds.
# Sentiment     :  [{'label': '5 stars', 'score': 0.8519112467765808}]
# Review comment:  absolutely stunning. just took me 15 to 20 mins and everything is automated 😍 love this app 🙏🏻
# Sentiment     :  [{'label': '5 stars', 'score': 0.9741902351379395}]
# Review comment:  Amazing
# Sentiment     :  [{'label': '5 stars', 'score': 0.8426642417907715}]
# Review comment:  It's Awesome app, i do recommend this, super, very good one
# Sentiment     :  [{'label': '5 stars', 'score': 0.8128318190574646}]
# Review comment:  Very poor
# Sentiment     :  [{'label': '1 star', 'score': 0.6927268505096436}]
# Review comment:  closes/crashes/throws errors often. Super early stage but I'm super excited for what it CAN BE.
# Sentiment     :  [{'label': '2 stars', 'score': 0.4295608699321747}]
# Review comment:  Scrap, annoying , nothing is happening after entering pan , it's simply says Something went wrong , we are working , report of the bug has been submitted , next day it's ask you update the app , if you try to update it won't update it just says downloading and intalling it breaks again it says please udate samething will be in loop in won't allow you exit of the app too annoying, waste of time , I believe this app has been deployed to collect pan details only nothing else ,scrap
# Sentiment     :  [{'label': '1 star', 'score': 0.8608269691467285}]
# Review comment:  Logging in still a hassle. I tried OTP aadhaar option . Not working.
# Sentiment     :  [{'label': '1 star', 'score': 0.6353347301483154}]
# Review comment:  Simple. Good.
# Sentiment     :  [{'label': '4 stars', 'score': 0.521880567073822}]
# Review comment:  Filing is so easy, it happened in secs
# Sentiment     :  [{'label': '5 stars', 'score': 0.4738057851791382}]
# Review comment:  super easy to file tax.. initially the p&l fetched report was wrong.. had to redo it again.. some technical glitches though..hope they address those down the line..
# Sentiment     :  [{'label': '4 stars', 'score': 0.6671543121337891}]
# Review comment:  it's simple and easy to read option.. I like it
# Sentiment     :  [{'label': '4 stars', 'score': 0.5663999319076538}]
# Review comment:  Yes they made it work. 🤩🤩
# Sentiment     :  [{'label': '5 stars', 'score': 0.3896181583404541}]
# Review comment:  Changing my review, you guys are back with a bang after initial glitch.. best wishes
# Sentiment     :  [{'label': '1 star', 'score': 0.26723384857177734}]
# Review comment:  not clear what's going on
# Sentiment     :  [{'label': '3 stars', 'score': 0.34727638959884644}]
# Review comment:  Worst application I have ever seen, most important application don't accept my PAN, it means this application is not for me. WHY?
# Sentiment     :  [{'label': '1 star', 'score': 0.9031695127487183}]
# Review comment:  Yeah its good . At first I was stuck but thank you to the developer .. resolved my issues
# Sentiment     :  [{'label': '4 stars', 'score': 0.48347964882850647}]
# Review comment:  Rating it 1 because it's not working at all.. when I am putting my Pan number it's not even moving to the next page. I don't know is it because I am first time filing ITR or not? I will change the rating Glyde if you guys can help me here before 31st dec. P.s- Changing it to 5 star as it is awesome and now working fine. Filed my ITR with a single click.
# Sentiment     :  [{'label': '1 star', 'score': 0.6994122266769409}]
# Review comment:  First attempt: Onboarding failed at Enter PAN. The team quickly responded and informed about a surge in new users creating a snag at their servers. Second try: Onboarding went smoothly. Really like the interface and the available options on the app. Some of the features from their Website are marked as coming soon. Can't wait to use these for the next tax cycle.
# Sentiment     :  [{'label': '4 stars', 'score': 0.3737916946411133}]
# Review comment:  Easy and quick..loved it
# Sentiment     :  [{'label': '5 stars', 'score': 0.7309203147888184}]
# Review comment:  Issue resolved
# Sentiment     :  [{'label': '3 stars', 'score': 0.30108436942100525}]
# Review comment:  Can't signup, after entering pan details, it just keeps on loading and nothing happens
# Sentiment     :  [{'label': '1 star', 'score': 0.5229877233505249}]
# Review comment:  It's not accepting my PAN card. When I input my PAN card it says something not right. **It worked later, so raising the stars. Yet to utilise the platform.
# Sentiment     :  [{'label': '2 stars', 'score': 0.39894071221351624}]
# Review comment:  AD video looks promising but am stuck right on page1, when i enter my PAN, It doesn't let me goto next step, noway to reach support there too apart from writing a review question on playstore hoping support looks in. Update: resolution from support, mentioning load, seems working now, still exploring
# Sentiment     :  [{'label': '3 stars', 'score': 0.3973534405231476}]
# Review comment:  thousand times i clicked CONTINUE after entering my pan no but it's stuck there only.. thanks for solving the issue.. i filed my ITR yesterday without facing any resistance
# Sentiment     :  [{'label': '1 star', 'score': 0.3949659466743469}]
# Review comment:  Extremely useful. User friendly. Very clean interface Thanks Quicko.
# Sentiment     :  [{'label': '5 stars', 'score': 0.7978705167770386}]
# Review comment:  Taxes on trading are always confusing, thanks for making them simple. Great work. Looking forward to more such work.
# Sentiment     :  [{'label': '5 stars', 'score': 0.6907476782798767}]
# Review comment:  Easy to use, was able to file my taxes in a snap😊
# Sentiment     :  [{'label': '5 stars', 'score': 0.6105327606201172}]
# Review comment:  This app would really help me file taxes as I'm really unaware of the concept. Kudos!
# Sentiment     :  [{'label': '1 star', 'score': 0.5724906921386719}]
# Review comment:  "Reveice" you mean receive right ? Very unpolished app! Atleast check the grammar at the OTP page.
# Sentiment     :  [{'label': '1 star', 'score': 0.6856545805931091}]
# Review comment:  Thank you it's done
# Sentiment     :  [{'label': '5 stars', 'score': 0.5868852734565735}]
# Review comment:  Never thought filing tax would be so easy. First time I didn't on my own. Amazing UI experience and anyone can understand easily.
# Sentiment     :  [{'label': '5 stars', 'score': 0.8415552973747253}]
# Review comment:  THANK YOU SO MUCH GLYDE AND ZERODHA
# Sentiment     :  [{'label': '5 stars', 'score': 0.4452061057090759}]
# Review comment:  looks promising.
# Sentiment     :  [{'label': '4 stars', 'score': 0.4457534849643707}]
# Review comment:  amazing, very easy, very smooth
# Sentiment     :  [{'label': '5 stars', 'score': 0.8924550414085388}]
# Review comment:  nice
# Sentiment     :  [{'label': '4 stars', 'score': 0.4368409514427185}]
# Review comment:  Good one 👍
# Sentiment     :  [{'label': '4 stars', 'score': 0.4954393208026886}]
# Review comment:  superb and easy to use. User friendly app👍
# Sentiment     :  [{'label': '5 stars', 'score': 0.8351237773895264}]
# Review comment:  Worst app .. after entering pan number enable to move to next process
# Sentiment     :  [{'label': '1 star', 'score': 0.8113641738891602}]
# Review comment:  Filling the tax has never been easy!
# Sentiment     :  [{'label': '2 stars', 'score': 0.23971588909626007}]
# Review comment:  phenomenal!
# Sentiment     :  [{'label': '5 stars', 'score': 0.9124076962471008}]
# Review comment:  I have some STCG ammount but this App showing STCG 0 (after connecting with zerodha). This app always have some problems. First completely build this app then upload on Play Store.
# Sentiment     :  [{'label': '1 star', 'score': 0.42396509647369385}]
# Review comment:  Information is not reliable. The app says ITR is pending while I have already filed the ITR a month ago and got acknowledgement as well.
# Sentiment     :  [{'label': '1 star', 'score': 0.6247022747993469}]
# Review comment:  Awesome Experience, 1st time I filed and no hassle at all.
# Sentiment     :  [{'label': '5 stars', 'score': 0.950616180896759}]
# Review comment:  Not detecting my PAN number
# Sentiment     :  [{'label': '1 star', 'score': 0.4612964689731598}]
# Review comment:  This App is the future of Filing Income tax return directly from your phone. App simplified the process to a greater extent. I will not visit my CA for ITR filing anymore. It will also save my time & CA Charges 😉👍🏻
# Sentiment     :  [{'label': '1 star', 'score': 0.3001713454723358}]
# Review comment:  Trying to file ITR from last 5 days, everything is complete but the quicko team not able to clear the bug
# Sentiment     :  [{'label': '1 star', 'score': 0.3555746376514435}]
# Review comment:  This app won't works
# Sentiment     :  [{'label': '1 star', 'score': 0.7746752500534058}]
# Review comment:  good
# Sentiment     :  [{'label': '4 stars', 'score': 0.49696317315101624}]
# Review comment:  It's Absolutely Awesome,Simplified And Very User friendly
# Sentiment     :  [{'label': '5 stars', 'score': 0.9121037125587463}]
# Review comment:  So I've been postponing my tax filing for months and 'glyde' does it in less than 5 minutes. It auto fetched all my returns from stocks from the broker's app directly. Highly Recommended!
# Sentiment     :  [{'label': '5 stars', 'score': 0.833497166633606}]
# Review comment:  it's working nice one swipe is enough to do it was very helpful application from zerodha happy to be with zerodha😊
# Sentiment     :  [{'label': '5 stars', 'score': 0.4953337013721466}]
# Review comment:  Never thought taxes could be this easy. It really simple to onboard. Can't wait for new features like they promised. Way to go team!
# Sentiment     :  [{'label': '5 stars', 'score': 0.5677534937858582}]
# Review comment:  Sign up is not happening after multiple attempts. App does not accept genuine PAN number and stays on "verify that's you" screen
# Sentiment     :  [{'label': '1 star', 'score': 0.640648603439331}]
# Review comment:  Does not accept my PAN no.and just stops there. Pathetic ! Something untested like this from Zerodha, dilutes Zerodha's reputation.
# Sentiment     :  [{'label': '1 star', 'score': 0.9435989856719971}]
# Review comment:  Not able to enter the application itself as app is not able to recognise my PAN itself. Please check this issue
# Sentiment     :  [{'label': '1 star', 'score': 0.5937204957008362}]
# Review comment:  Whenever i try to register on this app and fill v PAN number, it always say that this is wrong number please fill correct pan number. I tried using my family's pan number but probelm remains the same. Not worth when u cant even register on this app. Zero star.
# Sentiment     :  [{'label': '1 star', 'score': 0.9903689026832581}]
# Review comment:  Unable to login
# Sentiment     :  [{'label': '1 star', 'score': 0.6486161947250366}]
# Review comment:  Stuck at could not save your details.
# Sentiment     :  [{'label': '1 star', 'score': 0.41723620891571045}]
# Review comment:  Not accepting my PAN number!!
# Sentiment     :  [{'label': '1 star', 'score': 0.6815198659896851}]
# Review comment:  After filling in the pan number , it is showing can not save your details
# Sentiment     :  [{'label': '3 stars', 'score': 0.2570706307888031}]
# Review comment:  There is no rating less than one star so finding a problem to rate this one, keep on saying wrong PAN every time I entered correct one
# Sentiment     :  [{'label': '1 star', 'score': 0.9682570099830627}]
# Review comment:  Not working for me. When I enter my PAN it is saying it is wrong !!
# Sentiment     :  [{'label': '1 star', 'score': 0.6681329011917114}]
# Review comment:  Worst app
# Sentiment     :  [{'label': '1 star', 'score': 0.8914126753807068}]
# Review comment:  Not picking the pan card
# Sentiment     :  [{'label': '1 star', 'score': 0.4792933166027069}]
# Review comment:  first of all Pan number not recognized
# Sentiment     :  [{'label': '1 star', 'score': 0.362918883562088}]
# Review comment:  Not sure but it is not taking my correct pan number so can't even login to app
# Sentiment     :  [{'label': '3 stars', 'score': 0.4220770001411438}]
# Review comment:  Does not fetch details of valid PAN number, says Invalid
# Sentiment     :  [{'label': '1 star', 'score': 0.7505707144737244}]
# Review comment:  after entering Pan, error pop up.useless
# Sentiment     :  [{'label': '1 star', 'score': 0.8692474365234375}]
# Review comment:  Can't pass onboarding. First error by snging in with Google, second error when entering PAN. Wonder why it's backed by zerodha. And they deleted my review once. So here it is again.
# Sentiment     :  [{'label': '1 star', 'score': 0.6366140842437744}]
# Review comment:  It was really a gylding experience, thanks a lot for the app.
# Sentiment     :  [{'label': '5 stars', 'score': 0.4890997111797333}]
# Review comment:  Ye Pan Number check nahi kar pa raha tax kya bharega
# Sentiment     :  [{'label': '1 star', 'score': 0.2946045696735382}]
# Review comment:  Useless it is not recognize my PAN
# Sentiment     :  [{'label': '1 star', 'score': 0.8572171330451965}]
# Review comment:  It's not recognising the PAN number. It's saying always "hmm. that's not right. let's try again"
# Sentiment     :  [{'label': '1 star', 'score': 0.41032058000564575}]
# Review comment:  It's showing error when ever i tried to put my PAN no. What's the matter?
# Sentiment     :  [{'label': '1 star', 'score': 0.5709024667739868}]
# Review comment:  Failed to identify the pan itself in first step
# Sentiment     :  [{'label': '1 star', 'score': 0.44590336084365845}]
# Review comment:  Thankyou for the quick reply. Looks like you guys are getting popular. Looks like a nice app with good UI. Egarly waiting to try it.
# Sentiment     :  [{'label': '5 stars', 'score': 0.46813488006591797}]
# Review comment:  Pathetic. Stuck at first step. Even after entering right PAN, app errors out saying its incorrect.
# Sentiment     :  [{'label': '1 star', 'score': 0.8946118354797363}]
# Review comment:  Every time shows try agin when i enter the pan no.
# Sentiment     :  [{'label': '1 star', 'score': 0.5447593331336975}]
# Review comment:  Post entering pan no getting error message as try again error.
# Sentiment     :  [{'label': '1 star', 'score': 0.6211147904396057}]
# Review comment:  Not taking my pan no. It shows incorrect
# Sentiment     :  [{'label': '1 star', 'score': 0.7567075490951538}]
# Review comment:  Can't use the app, When it ask for PAN, i entered correct PAN number but it says "hmm thats not right, lets try again"
# Sentiment     :  [{'label': '1 star', 'score': 0.4840223491191864}]
# Review comment:  Not fetching my details after providing pan card details.
# Sentiment     :  [{'label': '2 stars', 'score': 0.40657126903533936}]
# Review comment:  Faltu app n support keep deleting my comments
# Sentiment     :  [{'label': '1 star', 'score': 0.4323697090148926}]
# Review comment:  It doesn't recognize Pan details n ask to verify it again n again
# Sentiment     :  [{'label': '1 star', 'score': 0.558894693851471}]
# Review comment:  Says my PAN is not right. I tried entering it like many times but how is that possible. Unless you don't support Indian PAN cards.
# Sentiment     :  [{'label': '1 star', 'score': 0.4010236859321594}]
# Review comment:  Geeting an error while entering my pan number
# Sentiment     :  [{'label': '1 star', 'score': 0.6411163210868835}]
# Review comment:  When I enter my PAN number it says "hmm that's not right please try again" and I tried with the correct PAN NUMBER
# Sentiment     :  [{'label': '1 star', 'score': 0.5620765089988708}]
# Review comment:  I am getting "hmm that's not correct" after entering correct PAN number.
# Sentiment     :  [{'label': '2 stars', 'score': 0.34806880354881287}]
# Review comment:  Not able to proceed as app is not able to recognize Pancard number.
# Sentiment     :  [{'label': '1 star', 'score': 0.5488835573196411}]
# Review comment:  It's saying that's not right,when I type in my PAN
# Sentiment     :  [{'label': '2 stars', 'score': 0.33461442589759827}]
# Review comment:  Says my pan number is wrong (I've checked multiple times) no option to do anything other than input pan
# Sentiment     :  [{'label': '1 star', 'score': 0.6531224846839905}]
# Review comment:  Pathetic , I am entering my pan it shows something not right. Waste of time.
# Sentiment     :  [{'label': '1 star', 'score': 0.8717138767242432}]
# Review comment:  Unable to even enter the pan details to move forward
# Sentiment     :  [{'label': '1 star', 'score': 0.5059581995010376}]
# Review comment:  Now it's asking pan no, even after entering correct pan no, it say couldn't sign in. Develop app properly before giving add on Zerodha. We trust Zerodha but ur app is useless. Not able to sign via Google, even after entering OTP it goes in hibernation mode. Useless app
# Sentiment     :  [{'label': '1 star', 'score': 0.7759155035018921}]
# Review comment:  Unable to update PAN - Showing incorrect after many times
# Sentiment     :  [{'label': '1 star', 'score': 0.4819575548171997}]
# Review comment:  Can't even start with this app. Whenever i am entering my PAN i am getting error, this is not right. Very bad user experience.
# Sentiment     :  [{'label': '1 star', 'score': 0.9023295640945435}]
# Review comment:  After entering my pan, it says that's not right....🙄🙄
# Sentiment     :  [{'label': '1 star', 'score': 0.45642805099487305}]
# Review comment:  I have enterd my pan no app says thats not right lets try again
# Sentiment     :  [{'label': '1 star', 'score': 0.5822762846946716}]
# Review comment:  My pan number shows me incorrect, I am several time but still show me incorrect
# Sentiment     :  [{'label': '2 stars', 'score': 0.3071659803390503}]
# Review comment:  Its saying my pan card isnt right. So plz tell me whats my correct pan card no. LoL
# Sentiment     :  [{'label': '1 star', 'score': 0.3789249062538147}]
# Review comment:  I am just starting the application and it took multiple attempts to signup with email or Google account. Now it is not accepting my PAN details and says "let's try again". I have tried multiple times. Not at all satisfied with the application.
# Sentiment     :  [{'label': '1 star', 'score': 0.603084146976471}]
# Review comment:  on-boarding did not work as expected.
# Sentiment     :  [{'label': '1 star', 'score': 0.49690181016921997}]
# Review comment:  It asks enter your pan. I entered the PAN number and pressed continue then it says that's not right let's try again. This is happening in a loop
# Sentiment     :  [{'label': '1 star', 'score': 0.57338947057724}]
# Review comment:  The app is not downloading, after 41%, the downloading gets stuck. I have restarted the phone, clear the cache memory and even changed the google account. Please resolve the issue at the earliest.
# ...
# Review comment:  No process after writing PAN number
# Sentiment     :  [{'label': '1 star', 'score': 0.56448894739151}]
# Review comment:  Worst app. It took 10 retry to send the code on my mail. After that it is not processing my PAN.
# Sentiment     :  [{'label': '1 star', 'score': 0.9029252529144287}]
# Review comment:  It is stuck at enter pan number details and no further action is taking place after filling Pan number.
# Sentiment     :  [{'label': '1 star', 'score': 0.4935152232646942}]
# Review comment:  All 5 stars are Fake reviews ..Not working for me...after entering pan I'd it does not proceed further
# Sentiment     :  [{'label': '1 star', 'score': 0.9020709991455078}]
# Review comment:  App is not working properly. Screen stops while taking pan card number. When I press continue after entering PAN, it is not proceeding further.
# Sentiment     :  [{'label': '1 star', 'score': 0.5711073279380798}]
# Review comment:  It's asking for PAN number and that's it. It's floating like a dead fish in the water.
# Sentiment     :  [{'label': '1 star', 'score': 0.45653045177459717}]
# Review comment:  Do not put your app on production if your app is not ready to handle the users. Put it in beta and test it properly before making it live. It's stucked at the pan page, not going forward. At least give a message to the users, why it's failing. Break with a scream is always better than silent break.
# Sentiment     :  [{'label': '1 star', 'score': 0.6670160889625549}]
# Review comment:  At the beginning when we need to enter pan after that nothing is loaded
# Sentiment     :  [{'label': '3 stars', 'score': 0.28255853056907654}]
# Review comment:  I'm entering my PAN but it's not moving forward.
# Sentiment     :  [{'label': '3 stars', 'score': 0.4235254228115082}]
# Review comment:  Improve your App There are to many bugs. I have tried 20 time to just login. Once successfully logged And after entering PAN the app is not going further.
# Sentiment     :  [{'label': '2 stars', 'score': 0.4018562138080597}]
# Review comment:  Stuck on PAN details page
# Sentiment     :  [{'label': '1 star', 'score': 0.43486154079437256}]
# Review comment:  Not connecting my pan...:-)
# Sentiment     :  [{'label': '1 star', 'score': 0.4000372588634491}]
# Review comment:  Stuck at entering pan details. Doesn't continue
# Sentiment     :  [{'label': '1 star', 'score': 0.6044438481330872}]
# Review comment:  Not even able to go on the next screen from entering the pan number
# Sentiment     :  [{'label': '1 star', 'score': 0.6588607430458069}]
# Review comment:  I am unable to register, needed PAN number but after that unable to proceed.
# Sentiment     :  [{'label': '1 star', 'score': 0.4424608051776886}]
# Review comment:  Not able to fetch detail after entering PAN card, not proceeding further
# Sentiment     :  [{'label': '2 stars', 'score': 0.4343545138835907}]
# Review comment:  I am not able to move beyond the first page, when it prompts user to enter the pan number
# Sentiment     :  [{'label': '1 star', 'score': 0.4315740764141083}]
# Review comment:  After entering my pan number. Nothing happening. Why???
# Sentiment     :  [{'label': '1 star', 'score': 0.6074304580688477}]
# Review comment:  Its says enter your PAN. AFTER ENTERING PAN and clicking on continue nothing happens
# Sentiment     :  [{'label': '1 star', 'score': 0.6623404622077942}]
# Review comment:  Unable to fetch data after entering PAN.
# Sentiment     :  [{'label': '1 star', 'score': 0.5009993314743042}]
# Review comment:  App has too many bugs 1. It takes a lot of time to even register 2. After n unsuccessful attempts when it finally registers you then again it takes forever to continue after entering PAN details Please look into it ASAP
# Sentiment     :  [{'label': '2 stars', 'score': 0.4116823375225067}]
# Review comment:  not qble to login
# Sentiment     :  [{'label': '1 star', 'score': 0.47759780287742615}]
# Review comment:  Not moving ahead of asking pan number. I think its very buggy.
# Sentiment     :  [{'label': '2 stars', 'score': 0.4860464632511139}]
# Review comment:  I was entered my PAN but it wasn't taking my PAN its not working properly...
# Sentiment     :  [{'label': '2 stars', 'score': 0.42928022146224976}]
# Review comment:  Not detecting PAN
# Sentiment     :  [{'label': '1 star', 'score': 0.4389844238758087}]
# Review comment:  It doesn't even go ahead after I enter my PAN during registration.
# Sentiment     :  [{'label': '1 star', 'score': 0.3777260482311249}]
# Review comment:  App is crashing multiple times after giving email app can't proceed further..stuck on only PAN card number page... Fix this SLOW issue STUCK issue
# Sentiment     :  [{'label': '1 star', 'score': 0.7495961785316467}]
# Review comment:  I am entering my pan and pressing continue but I'm not moving forward and getting my otp, it's not working
# Sentiment     :  [{'label': '2 stars', 'score': 0.4570714235305786}]
# Review comment:  N ot able to login after entering PAN. Please help
# Sentiment     :  [{'label': '5 stars', 'score': 0.2808040380477905}]
# Review comment:  Can move ahead of entring pan while signup ? App is not working ?
# Sentiment     :  [{'label': '1 star', 'score': 0.5432517528533936}]
# Review comment:  it is not working after entering pan number and pressing continue button. Nothing happens except three dots dancing on continue button... funny
# Sentiment     :  [{'label': '1 star', 'score': 0.6077592372894287}]
# Review comment:  Nothing happens when i put my pancard number and press continue
# Sentiment     :  [{'label': '1 star', 'score': 0.5756403207778931}]
# Review comment:  It's not taking PAN itself I m fed up pressing continue continue Continue
# Sentiment     :  [{'label': '1 star', 'score': 0.43353188037872314}]
# Review comment:  After entering pan, it's not not moving to next screen.. stuck in the same screen.
# Sentiment     :  [{'label': '1 star', 'score': 0.5333607792854309}]
# Review comment:  Unable to login. Page is stuck at PAN number page.
# Sentiment     :  [{'label': '1 star', 'score': 0.691526472568512}]
# Review comment:  After signing in with Google, I entered my PAN no, but it is stuck there. It is not going to next screen
# Sentiment     :  [{'label': '1 star', 'score': 0.42847469449043274}]
# Review comment:  Got stuck in enter your PAN screen. Disappointed😞
# Sentiment     :  [{'label': '1 star', 'score': 0.4919184148311615}]
# Review comment:  Doesn't proceed after entering PAN itself, showing loader for very long and then again continue button. Need fast and smooth experience.
# Sentiment     :  [{'label': '2 stars', 'score': 0.4707476794719696}]
# Review comment:  After I enter PAN number it's not going to the next step .. tried multiple times..
# Sentiment     :  [{'label': '1 star', 'score': 0.450440376996994}]
# Review comment:  After entering pan no it's not getting continue, it's stuck .
# Sentiment     :  [{'label': '1 star', 'score': 0.4993775486946106}]
# Review comment:  After giving pan number....it's not working
# Sentiment     :  [{'label': '1 star', 'score': 0.6008636951446533}]
# Review comment:  After entering the pan card details taking to much time to load and not showing any error
# Sentiment     :  [{'label': '5 stars', 'score': 0.3044230341911316}]
# Review comment:  Cannot login to the app, stuck after entering PAN details.
# Sentiment     :  [{'label': '1 star', 'score': 0.561188280582428}]
# Review comment:  After I entered PAN it goes no where. Just stuck at continue loader. Please do something about it.
# Sentiment     :  [{'label': '1 star', 'score': 0.5961908102035522}]
# Review comment:  I not able to register with my gmail account. After changing multiple email id, got the OTP. But then it's not accepting my PAN CARD to continue initial registration.
# Sentiment     :  [{'label': '1 star', 'score': 0.5260429382324219}]
# Review comment:  It does not move to next step from pan ID
# Sentiment     :  [{'label': '1 star', 'score': 0.5193027257919312}]
# Review comment:  After entering the pan number it just keeps on loading .........
# Sentiment     :  [{'label': '3 stars', 'score': 0.2986812889575958}]
# Review comment:  Not working
# Sentiment     :  [{'label': '1 star', 'score': 0.6374980807304382}]
# Review comment:  Not able to proceed to next screen after entering the PAN. The continue button keeps on loading.
# Sentiment     :  [{'label': '1 star', 'score': 0.4896027743816376}]
# Review comment:  I installed the app but after entering the pan card details it not going forward
# Sentiment     :  [{'label': '2 stars', 'score': 0.347570538520813}]
# Review comment:  Asks for PAN number and doesn't proceed after that page. Expected better experience. Please fix the bug ASAP.
# Sentiment     :  [{'label': '2 stars', 'score': 0.40493032336235046}]
# Review comment:  Intro of the app is good but not able to get OTP and deficult to log in very slow
# Sentiment     :  [{'label': '2 stars', 'score': 0.3879297971725464}]
# Review comment:  Bad experience. Not fetching my pan card details.
# Sentiment     :  [{'label': '1 star', 'score': 0.7390327453613281}]
# Review comment:  Extremely buggy, not able to login.
# Sentiment     :  [{'label': '1 star', 'score': 0.7448782324790955}]
# Review comment:  Not working
# Sentiment     :  [{'label': '1 star', 'score': 0.6374980807304382}]
# Review comment:  Unable to continue after entering my PAN card
# Sentiment     :  [{'label': '1 star', 'score': 0.5024231672286987}]
# Review comment:  Nothing is happening when I entered my PAN
# Sentiment     :  [{'label': '1 star', 'score': 0.5540807247161865}]
# Review comment:  Not getting Started after entering pan still not going forward.
# Sentiment     :  [{'label': '1 star', 'score': 0.4128720164299011}]
# Review comment:  Can't login Won't move forward after pan number very difficult to glyde actually
# Sentiment     :  [{'label': '1 star', 'score': 0.6528182625770569}]
# Review comment:  It's not opening
# Sentiment     :  [{'label': '1 star', 'score': 0.5414907336235046}]
# Review comment:  Talking way too much time to check otp. Couldn't login 👎
# Sentiment     :  [{'label': '1 star', 'score': 0.47572287917137146}]
# Review comment:  Not able to retrieve details
# Sentiment     :  [{'label': '2 stars', 'score': 0.4117763340473175}]
# Review comment:  Super slow onboarding. Eventually got stuck at the screen where it asked for my PAN, app unable to proceed further.
# Sentiment     :  [{'label': '2 stars', 'score': 0.4679340720176697}]
# Review comment:  Doesn't work . My pan number not taken
# Sentiment     :  [{'label': '1 star', 'score': 0.8353572487831116}]
# Review comment:  The app is useful, though it doesn't work after I put in the PAN number, I press continue but it just stays that way.
# Sentiment     :  [{'label': '3 stars', 'score': 0.4913703501224518}]
# Review comment:  Login not working....
# Sentiment     :  [{'label': '1 star', 'score': 0.6562668681144714}]
# Review comment:  Can't get onboard, doesn't go past the PAN entry pg
# Sentiment     :  [{'label': '1 star', 'score': 0.5685137510299683}]
# Review comment:  Unavailable to sign in because not sending OTP and showing error
# Sentiment     :  [{'label': '1 star', 'score': 0.67527836561203}]
# Review comment:  Not a good app, I didn't get the OTP on Google account or Gmail. Said could not sign in or something went wrong.
# Sentiment     :  [{'label': '1 star', 'score': 0.5973525047302246}]
# Review comment:  When I enter my PAN Number it says it's invalid.. Some bug with the App
# Sentiment     :  [{'label': '1 star', 'score': 0.4447970986366272}]
# Review comment:  Could not even sign in to the app
# Sentiment     :  [{'label': '1 star', 'score': 0.5934537649154663}]
# Review comment:  Quicko tax filing is awesome.
# Sentiment     :  [{'label': '5 stars', 'score': 0.7779136300086975}]
# Review comment:  It's not working
# Sentiment     :  [{'label': '1 star', 'score': 0.5992379188537598}]
# Review comment:  This app unable to detect my PAN
# Sentiment     :  [{'label': '1 star', 'score': 0.4884395897388458}]
# Review comment:  Doesn't take PAN
# Sentiment     :  [{'label': '1 star', 'score': 0.4879714548587799}]
# Review comment:  I want to upload trading income.. But excel option is not functional... My broker is icici direct.. When will the excel option will become functional?
# Sentiment     :  [{'label': '2 stars', 'score': 0.36042141914367676}]
# Review comment:  Failed to fetch information from ITD site. All the information is already present in ITD site but the app says to fill all the information
# Sentiment     :  [{'label': '1 star', 'score': 0.5892589092254639}]
# Review comment:  After filling all the details it's prompts like 'swipe to e-file'. But when I swipe it, it's not working.
# Sentiment     :  [{'label': '2 stars', 'score': 0.4951682686805725}]
# Review comment:  It's saying connection to ITD failed (although single factor authentication is enabled)
# Sentiment     :  [{'label': '1 star', 'score': 0.46729224920272827}]
# Review comment:  Amazing app. It was a breeze to file the taxes and worked like a charm.
# Sentiment     :  [{'label': '5 stars', 'score': 0.8802967071533203}]
# Review comment:  Filed itr for the first time. thanks to Glyde it was super simple. great job team
# Sentiment     :  [{'label': '5 stars', 'score': 0.7171450853347778}]
# Review comment:  Verynice thankyou
# Sentiment     :  [{'label': '5 stars', 'score': 0.5366773009300232}]
# Review comment:  I just want explore the app 1st without give financial details. Thats a no go for me...
# Sentiment     :  [{'label': '2 stars', 'score': 0.40891847014427185}]
# Review comment:  Its asking for ITD password which i dont know. How can i procedd ??
# Sentiment     :  [{'label': '3 stars', 'score': 0.25618976354599}]
# Review comment:  This app is seriously dope. It literally makes taxes a child's play. The UI is so funky and chic. Highly recommended
# Sentiment     :  [{'label': '1 star', 'score': 0.3468000292778015}]
# Review comment:  Smooth, simple and easy! Absolutely love the interface. Filing my return has never been this easy.
# Sentiment     :  [{'label': '5 stars', 'score': 0.9142026305198669}]
# Review comment:  Kudos. I was waiting for this.
# Sentiment     :  [{'label': '1 star', 'score': 0.2596030831336975}]
# Review comment:  Perfect👍
# Sentiment     :  [{'label': '5 stars', 'score': 0.3085777759552002}]
# Review comment:  Never imagined about such experience for doing taxes. Excited about the upcoming feature updates.
# Sentiment     :  [{'label': '2 stars', 'score': 0.414079487323761}]
# Review comment:  Smooth experience like nowhere else. Good job 👍
# Sentiment     :  [{'label': '5 stars', 'score': 0.47784772515296936}]
# Review comment:  Filed my income tax return with glyde, super easy to use and very smooth interface. Highly recommended to file your income tax return.
# Sentiment     :  [{'label': '5 stars', 'score': 0.8564581274986267}]
# Review comment:  Never Imagined Files Taxes could be just not easy but Interesting too. The app is really young and lively. Kudos to the team 🌟
# Sentiment     :  [{'label': '4 stars', 'score': 0.5150317549705505}]
# Review comment:  Super easy to file taxes through the app. After the broker integration, now the mobile application, Quicko is contributing a lot in making a 21st century "New India - Digital India" 🇮🇳
# Sentiment     :  [{'label': '5 stars', 'score': 0.6921995282173157}]
# Review comment:  Great to see the team is still so much committed after delivering consistent excellence. This is the initial version but stil it brings e-filing on your fingertips. I must admit that Quicko is really good at smoke signals they understands the need of an hour. Wishing them all the success for their upcoming versions with much more intuitive UI and amazing user experience with awesome features.
# Sentiment     :  [{'label': '5 stars', 'score': 0.5800679326057434}]
# Review comment:  Sweet, Simple & incredible Ui/Ux design. Filling ITR is easy swipe,slide pay your ITR with the glyde.
# Sentiment     :  [{'label': '5 stars', 'score': 0.7999747395515442}]
# Review comment:  Filed my first tax return with this app. It was a great experience. Looking forward to future updates.
# Sentiment     :  [{'label': '5 stars', 'score': 0.43765687942504883}]

# %%
# sentiment of all user reviews
sentiment_list = []

for index, row in reviews_df.iterrows():
    review_comment = row['content']
    sentiment = sentiment_pipeline(review_comment)
    sentiment_list.append(sentiment)
print(sentiment_list)
# Out:
# [[{'label': '5 stars', 'score': 0.6665805578231812}], [{'label': '5 stars', 'score': 0.8769167065620422}], [{'label': '5 stars', 'score': 0.8367269039154053}], [{'label': '1 star', 'score': 0.3641238808631897}], [{'label': '3 stars', 'score': 0.3997366428375244}], [{'label': '3 stars', 'score': 0.4484536349773407}], [{'label': '5 stars', 'score': 0.5438485741615295}], [{'label': '1 star', 'score': 0.48022183775901794}], [{'label': '5 stars', 'score': 0.8146355152130127}], [{'label': '5 stars', 'score': 0.8669129014015198}], [{'label': '5 stars', 'score': 0.6379151344299316}], [{'label': '5 stars', 'score': 0.8875816464424133}], [{'label': '5 stars', 'score': 0.5479444861412048}], [{'label': '5 stars', 'score': 0.4883631467819214}], [{'label': '4 stars', 'score': 0.515525221824646}], [{'label': '1 star', 'score': 0.43716540932655334}], [{'label': '5 stars', 'score': 0.37271276116371155}], [{'label': '3 stars', 'score': 0.372996985912323}], [{'label': '5 stars', 'score': 0.8669129014015198}], [{'label': '5 stars', 'score': 0.9034099578857422}], [{'label': '5 stars', 'score': 0.734377384185791}], [{'label': '5 stars', 'score': 0.8887758851051331}], [{'label': '5 stars', 'score': 0.8669129014015198}], [{'label': '5 stars', 'score': 0.5387366414070129}], [{'label': '5 stars', 'score': 0.5766907334327698}], [{'label': '5 stars', 'score': 0.6515334844589233}], [{'label': '1 star', 'score': 0.43660199642181396}], [{'label': '5 stars', 'score': 0.8726432919502258}], [{'label': '5 stars', 'score': 0.2611572742462158}], [{'label': '2 stars', 'score': 0.35015279054641724}], [{'label': '5 stars', 'score': 0.8005624413490295}], [{'label': '4 stars', 'score': 0.7690916657447815}], [{'label': '5 stars', 'score': 0.4819522202014923}], [{'label': '5 stars', 'score': 0.9123279452323914}], [{'label': '5 stars', 'score': 0.9361116886138916}], [{'label': '1 star', 'score': 0.6250942945480347}], [{'label': '5 stars', 'score': 0.759162187576294}], [{'label': '2 stars', 'score': 0.3710624873638153}], [{'label': '5 stars', 'score': 0.4990110993385315}], [{'label': '5 stars', 'score': 0.8114801645278931}], [{'label': '4 stars', 'score': 0.46905526518821716}], [{'label': '5 stars', 'score': 0.8146355152130127}], [{'label': '5 stars', 'score': 0.836195170879364}], [{'label': '5 stars', 'score': 0.6022850871086121}], [{'label': '1 star', 'score': 0.7717733979225159}], [{'label': '3 stars', 'score': 0.34332242608070374}], [{'label': '2 stars', 'score': 0.4927073121070862}], [{'label': '3 stars', 'score': 0.4598027765750885}], [{'label': '5 stars', 'score': 0.8580580353736877}], [{'label': '5 stars', 'score': 0.5379349589347839}], [{'label': '1 star', 'score': 0.44111865758895874}], [{'label': '1 star', 'score': 0.41347837448120117}], [{'label': '1 star', 'score': 0.47506409883499146}], [{'label': '4 stars', 'score': 0.4694801867008209}], [{'label': '4 stars', 'score': 0.6078701019287109}], [{'label': '5 stars', 'score': 0.8196687698364258}], [{'label': '5 stars', 'score': 0.6279726624488831}], [{'label': '1 star', 'score': 0.5822308659553528}], [{'label': '5 stars', 'score': 0.6515334844589233}], [{'label': '4 stars', 'score': 0.46105891466140747}], [{'label': '5 stars', 'score': 0.7573994398117065}], [{'label': '5 stars', 'score': 0.8959237933158875}], [{'label': '2 stars', 'score': 0.3765648901462555}], [{'label': '1 star', 'score': 0.6975002288818359}], [{'label': '1 star', 'score': 0.8121778964996338}], [{'label': '3 stars', 'score': 0.3655748665332794}], [{'label': '5 stars', 'score': 0.6533243656158447}], [{'label': '5 stars', 'score': 0.7317835688591003}], [{'label': '5 stars', 'score': 0.6936805248260498}], [{'label': '5 stars', 'score': 0.733465313911438}], [{'label': '5 stars', 'score': 0.9370108842849731}], [{'label': '5 stars', 'score': 0.9067445993423462}], [{'label': '5 stars', 'score': 0.9008098244667053}], [{'label': '5 stars', 'score': 0.4850592017173767}], [{'label': '3 stars', 'score': 0.36313024163246155}], [{'label': '1 star', 'score':  ...

# %% [markdown]
# ---
# ### Part 3: Creating the final dataset by merging the reviews and sentiments

# %%
# creating a CSV file for all the sentiments
sentiment_df = pd.read_csv("sentiments.csv")
sentiment_df.head()
# Out:
#      label     score
# 0  5 stars  0.666581
# 1  5 stars  0.876917
# 2  5 stars  0.836727
# 3   1 star  0.364124
# 4  3 stars  0.399737

# %%
# combining the reviews and sentiments dataframes
combined_df = pd.concat([reviews_df, sentiment_df], axis=1)

# %%
# displaying the top 5 rows of the combined dataframe
combined_df.head()
# Out:
#                                              content  score  thumbsUpCount  \
# 0  Easy and convenience. Anyone can easily fill i...      5              0
# 1                                          Awesome!!      5              0
# 2    marvelous great experience soooooooo smooooooth      5              0
# 3  Wazirx india crypto platform is not available....      1              0
# 4  App is good and simple but not showing angel o...      5              0
#
#   reviewCreatedVersion                at  \
# 0                2.6.2  24-07-2023 19:20
# 1                2.6.2  24-07-2023 13:26
# 2                2.6.2  24-07-2023 12:47
# 3                2.6.2  24-07-2023 10:30
# 4                2.6.2  24-07-2023 07:35
#
#                                         replyContent         repliedAt  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3  Hey Abhay, Nachiketa here. I'm the developer o...  24-07-2023 11:36
# 4  Hey there! AngelOne integration is now live on...  24-07-2023 21:05
#
#      label     score
# 0  5 stars  0.666581
# 1  5 stars  0.876917
# 2  5 stars  0.836727
# 3   1 star  0.364124
# 4  3 stars  0.399737

# %%
# displaying the bottom 5 rows of the combined dataframe
combined_df.tail()
# Out:
#                                                content  score  thumbsUpCount  \
# 425  Never Imagined Files Taxes could be just not e...      5              4
# 426  Super easy to file taxes through the app. Afte...      5              2
# 427  Great to see the team is still so much committ...      5             53
# 428  Sweet, Simple & incredible Ui/Ux design. Filli...      5             20
# 429  Filed my first tax return with this app. It wa...      5              4
#
#     reviewCreatedVersion                at  \
# 425                0.1.0  26-11-2021 10:34
# 426                0.1.0  26-11-2021 09:01
# 427                0.1.0  25-11-2021 22:22
# 428                0.1.0  25-11-2021 21:35
# 429                  NaN  25-11-2021 20:05
#
#                                           replyContent         repliedAt  \
# 425                                                NaN               NaN
# 426                                                NaN               NaN
# 427                                                NaN               NaN
# 428                                                NaN               NaN
# 429  Hey, Nachiketa. Thank you for checking out gly...  25-11-2021 20:09
#
#        label     score
# 425  4 stars  0.515032
# 426  5 stars  0.692200
# 427  5 stars  0.580068
# 428  5 stars  0.799975
# 429  5 stars  0.437657

# %% [markdown]
# ---
# ### Part 4: Cleaning the dataset

# %%
# renaming the columns and standardizing the label column
new_column_names = {'content': 'userReview', 'at': 'review_datetime', 'label': 'sentimentRating'}
combined_df = combined_df.rename(columns = new_column_names)

# %%
# standardizing the sentimentRating column
replace_dict = {'5 stars': '5 star', '4 stars': '4 star', '3 stars': '3 star', '2 stars': '2 star', '1 stars': '1 star'}
combined_df['sentimentRating'] = combined_df['sentimentRating'].replace(replace_dict)

# %%
# displaying the top 5 rows of the combined dataframe
combined_df.head()
# Out:
#                                           userReview  score  thumbsUpCount  \
# 0  Easy and convenience. Anyone can easily fill i...      5              0
# 1                                          Awesome!!      5              0
# 2    marvelous great experience soooooooo smooooooth      5              0
# 3  Wazirx india crypto platform is not available....      1              0
# 4  App is good and simple but not showing angel o...      5              0
#
#   reviewCreatedVersion   review_datetime  \
# 0                2.6.2  24-07-2023 19:20
# 1                2.6.2  24-07-2023 13:26
# 2                2.6.2  24-07-2023 12:47
# 3                2.6.2  24-07-2023 10:30
# 4                2.6.2  24-07-2023 07:35
#
#                                         replyContent         repliedAt  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3  Hey Abhay, Nachiketa here. I'm the developer o...  24-07-2023 11:36
# 4  Hey there! AngelOne integration is now live on...  24-07-2023 21:05
#
#   sentimentRating  sentimentScore
# 0          5 star        0.666581
# 1          5 star        0.876917
# 2          5 star        0.836727
# 3          1 star        0.364124
# 4          3 star        0.399737

# %%
# displaying the bottom 5 rows of the combined dataframe
combined_df.tail()
# Out:
#                                             userReview  score  thumbsUpCount  \
# 425  Never Imagined Files Taxes could be just not e...      5              4
# 426  Super easy to file taxes through the app. Afte...      5              2
# 427  Great to see the team is still so much committ...      5             53
# 428  Sweet, Simple & incredible Ui/Ux design. Filli...      5             20
# 429  Filed my first tax return with this app. It wa...      5              4
#
#     reviewCreatedVersion   review_datetime  \
# 425                0.1.0  26-11-2021 10:34
# 426                0.1.0  26-11-2021 09:01
# 427                0.1.0  25-11-2021 22:22
# 428                0.1.0  25-11-2021 21:35
# 429                  NaN  25-11-2021 20:05
#
#                                           replyContent         repliedAt  \
# 425                                                NaN               NaN
# 426                                                NaN               NaN
# 427                                                NaN               NaN
# 428                                                NaN               NaN
# 429  Hey, Nachiketa. Thank you for checking out gly...  25-11-2021 20:09
#
#     sentimentRating  sentimentScore
# 425          4 star        0.515032
# 426          5 star        0.692200
# 427          5 star        0.580068
# 428          5 star        0.799975
# 429          5 star        0.437657

# %%
# exporting the combined dataframe to a new CSV file
combined_df.to_csv('final.csv', index=False)
